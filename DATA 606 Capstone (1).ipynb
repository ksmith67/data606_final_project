# %% [markdown]
# # Dietary Restriction AI

# %% [markdown]
# ### Import Packages

# %%
pip install langchain_community pandas pyspark sentence_transformers tokenizers faiss-cpu textstat nltk
# Out:
# Requirement already satisfied: langchain_community in ./lib/python3.13/site-packages (0.3.20)
# Requirement already satisfied: pandas in ./lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: pyspark in ./lib/python3.13/site-packages (3.5.5)
# Requirement already satisfied: sentence_transformers in ./lib/python3.13/site-packages (4.0.1)
# Requirement already satisfied: tokenizers in ./lib/python3.13/site-packages (0.21.1)
# Requirement already satisfied: faiss-cpu in ./lib/python3.13/site-packages (1.10.0)
# Requirement already satisfied: textstat in ./lib/python3.13/site-packages (0.7.5)
# Requirement already satisfied: nltk in ./lib/python3.13/site-packages (3.9.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.45 in ./lib/python3.13/site-packages (from langchain_community) (0.3.47)
# Requirement already satisfied: langchain<1.0.0,>=0.3.21 in ./lib/python3.13/site-packages (from langchain_community) (0.3.21)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./lib/python3.13/site-packages (from langchain_community) (2.0.39)
# Requirement already satisfied: requests<3,>=2 in ./lib/python3.13/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./lib/python3.13/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./lib/python3.13/site-packages (from langchain_community) (3.11.14)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./lib/python3.13/site-packages (from langchain_community) (9.0.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./lib/python3.13/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in ./lib/python3.13/site-packages (from langchain_community) (2.8.1)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in ./lib/python3.13/site-packages (from langchain_community) (0.3.18)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./lib/python3.13/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy<3,>=1.26.2 in ./lib/python3.13/site-packages (from langchain_community) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: py4j==0.10.9.7 in ./lib/python3.13/site-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in ./lib/python3.13/site-packages (from sentence_transformers) (4.50.3)
# Requirement already satisfied: tqdm in ./lib/python3.13/site-packages (from sentence_transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in ./lib/python3.13/site-packages (from sentence_transformers) (2.6.0)
# Requirement already satisfied: scikit-learn in ./lib/python3.13/site-packages (from sentence_transformers) (1.6.1)
# Requirement already satisfied: scipy in ./lib/python3.13/site-packages (from sentence_transformers) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in ./lib/python3.13/site-packages (from sentence_transformers) (0.30.1)
# Requirement already satisfied: Pillow in ./lib/python3.13/site-packages (from sentence_transformers) (11.2.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in ./lib/python3.13/site-packages (from sentence_transformers) (4.12.2)
# Requirement already satisfied: packaging in ./lib/python3.13/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: pyphen in ./lib/python3.13/site-packages (from textstat) (0.17.2)
# Requirement already satisfied: cmudict in ./lib/python3.13/site-packages (from textstat) (1.0.32)
# Requirement already satisfied: setuptools in ./lib/python3.13/site-packages (from textstat) (77.0.3)
# Requirement already satisfied: click in ./lib/python3.13/site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in ./lib/python3.13/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in ./lib/python3.13/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.18.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./lib/python3.13/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: filelock in ./lib/python3.13/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./lib/python3.13/site-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2025.3.2)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.7 in ./lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.21->langchain_community) (0.3.7)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./lib/python3.13/site-packages (from langchain<1.0.0,>=0.3.21->langchain_community) (2.10.6)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./lib/python3.13/site-packages (from langchain-core<1.0.0,>=0.3.45->langchain_community) (1.33)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (3.10.15)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in ./lib/python3.13/site-packages (from langsmith<0.4,>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: six>=1.5 in ./lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.13/site-packages (from requests<3,>=2->langchain_community) (2025.1.31)
# Requirement already satisfied: networkx in ./lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in ./lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (3.1.6)
# Requirement already satisfied: sympy==1.13.1 in ./lib/python3.13/site-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./lib/python3.13/site-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: safetensors>=0.4.3 in ./lib/python3.13/site-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.5.3)
# Requirement already satisfied: importlib-metadata>=5 in ./lib/python3.13/site-packages (from cmudict->textstat) (8.6.1)
# Requirement already satisfied: importlib-resources>=5 in ./lib/python3.13/site-packages (from cmudict->textstat) (6.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./lib/python3.13/site-packages (from scikit-learn->sentence_transformers) (3.6.0)
# Requirement already satisfied: anyio in ./lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in ./lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in ./lib/python3.13/site-packages (from importlib-metadata>=5->cmudict->textstat) (3.21.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./lib/python3.13/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.45->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.21->langchain_community) (2.27.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./lib/python3.13/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./lib/python3.13/site-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Requirement already satisfied: sniffio>=1.1 in ./lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_community) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.llms import Ollama
import os
import json
import pandas as pd 
import numpy as np
import tempfile 
from pyspark.sql import SparkSession

import pyspark.sql.functions as f
from pyspark.sql import Row
from sentence_transformers import SentenceTransformer
import faiss
import ollama

import re
from pyspark.sql.types import StringType, FloatType, MapType

# %% [markdown]
# ### Initialize a Spark Session

# %%
spark = SparkSession.builder \
    .appName("Local Spark") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/20 19:10:40 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ### Data Ingestion
# In order to be compatible with LLM that we will be creating, the data needs to be processed to be in an efficient retrieval format and stored in a searchable index.
#
# ##### Recipe Data
# Our recipe data is sourced from web-scraped data containing

# %%
all_files = os.listdir("./")
recipe_files = [file for file in all_files if "recipes_raw_nosource" in file]

df_list = []

for file_name in recipe_files: 
    temp_path = os.path.join(tempfile.gettempdir(), file_name)
    
    with open(file_name, "r", encoding="utf-8") as file:
        data = json.load(file)

    file_df = pd.DataFrame.from_dict(data, orient="index")
    df_list.append(file_df)  # Collect DataFrame
    
# Concatenate all dataframes
recipes_df = pd.concat(df_list)

# select only title, ingredient, instructions columns
recipes_df = recipes_df[['title', 'ingredients', 'instructions']]

# repartition the dataframe 
recipes_df = spark.createDataFrame(recipes_df)
recipes_df = recipes_df.repartition(100)

recipes_df.show()
# Out:
# 25/04/20 19:10:44 WARN TaskSetManager: Stage 0 contains a task of very large size (16301 KiB). The maximum recommended task size is 1000 KiB.
# +--------------------+--------------------+--------------------+
# |               title|         ingredients|        instructions|
# +--------------------+--------------------+--------------------+
# |  Baked Greens Chips|[6 to 8 ounces he...|Watch how to make...|
# |Sweet Potato-Chic...|[2 large sweet po...|To prepare the ha...|
# |         Cali Burger|[1/4 cup mayonnai...|For the chipotle ...|
# |Oatmeal Cream Che...|[2 sticks unsalte...|Preheat the oven ...|
# |    Campari Spritzer|[1 (12-ounce) can...|Stir the orange j...|
# |Seared Rack of La...|[1/2 cup pistachi...|Watch how to make...|
# |         Cream Puffs|[6 tablespoons un...|Special equipment...|
# |Italian Style Hot...|[Cooking oil, sui...|In a saucepan ove...|
# |    Crab Cakes Salad|[2 tablespoons fi...|For the salad: Co...|
# |      Hot Cross Buns|[2 ounces fresh y...|Crumble the yeast...|
# |Strawberries with...|[4 pints (8 cups)...|Thirty minutes to...|
# |       Curry Chicken|[2 pounds chicken...|Put the sliced ch...|
# |Golden Squash Blo...|[1 1/2 tablespoon...|The broth: In a 4...|
# |Mexican Hot Choco...|[4 cups whole mil...|For the base: Add...|
# |Georgian Short Ri...|[5 pounds cross c...|In a heavy casser...|
# |    Chicken Milanese|[1 pound thin-cut...|Marinate the chic...|
# |Citrus Marinated ...|[1 pound large gr...|Drain the olives ...|
# |Beet-and-Potato L...|[2 medium russet ...|Preheat the oven ...|
# |Green Tea and Gin...|[3 cups water, 1/...|Bring a tea kettl...|
# |Jalapeno Cheese B...|                  []|Mix 2 tablespoons...|
# +--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ##### Cooking Literature Data
#
# The cooking literature data was pre-processed from PDF text files into a usable format in another notebook.

# %% [markdown]
# ### Data Chunking
# ##### Recipes Data
# The data was chunked into recipe-level chunks, since the recipes will then be able toi be referenced individually when needed. Since this use case is about modifying recipes in their entirety, we want the model to be able to reference the recipes in their entirety during its retrieval process.

# %%
recipes_df_chunk = recipes_df.withColumn("chunk_text", 
                                         f.concat_ws("\n", f.col("title"), f.col("ingredients"), f.col("instructions")))
recipes_df_chunk.show()
# Out:
# 25/04/20 19:15:49 WARN TaskSetManager: Stage 4 contains a task of very large size (16301 KiB). The maximum recommended task size is 1000 KiB.
# +--------------------+--------------------+--------------------+--------------------+
# |               title|         ingredients|        instructions|          chunk_text|
# +--------------------+--------------------+--------------------+--------------------+
# |  Baked Greens Chips|[6 to 8 ounces he...|Watch how to make...|Baked Greens Chip...|
# |Sweet Potato-Chic...|[2 large sweet po...|To prepare the ha...|Sweet Potato-Chic...|
# |         Cali Burger|[1/4 cup mayonnai...|For the chipotle ...|Cali Burger\n1/4 ...|
# |Oatmeal Cream Che...|[2 sticks unsalte...|Preheat the oven ...|Oatmeal Cream Che...|
# |    Campari Spritzer|[1 (12-ounce) can...|Stir the orange j...|Campari Spritzer\...|
# |Seared Rack of La...|[1/2 cup pistachi...|Watch how to make...|Seared Rack of La...|
# |         Cream Puffs|[6 tablespoons un...|Special equipment...|Cream Puffs\n6 ta...|
# |Italian Style Hot...|[Cooking oil, sui...|In a saucepan ove...|Italian Style Hot...|
# |    Crab Cakes Salad|[2 tablespoons fi...|For the salad: Co...|Crab Cakes Salad\...|
# |      Hot Cross Buns|[2 ounces fresh y...|Crumble the yeast...|Hot Cross Buns\n2...|
# |Strawberries with...|[4 pints (8 cups)...|Thirty minutes to...|Strawberries with...|
# |       Curry Chicken|[2 pounds chicken...|Put the sliced ch...|Curry Chicken\n2 ...|
# |Golden Squash Blo...|[1 1/2 tablespoon...|The broth: In a 4...|Golden Squash Blo...|
# |Mexican Hot Choco...|[4 cups whole mil...|For the base: Add...|Mexican Hot Choco...|
# |Georgian Short Ri...|[5 pounds cross c...|In a heavy casser...|Georgian Short Ri...|
# |    Chicken Milanese|[1 pound thin-cut...|Marinate the chic...|Chicken Milanese\...|
# |Citrus Marinated ...|[1 pound large gr...|Drain the olives ...|Citrus Marinated ...|
# |Beet-and-Potato L...|[2 medium russet ...|Preheat the oven ...|Beet-and-Potato L...|
# |Green Tea and Gin...|[3 cups water, 1/...|Bring a tea kettl...|Green Tea and Gin...|
# |Jalapeno Cheese B...|                  []|Mix 2 tablespoons...|Jalapeno Cheese B...|
# +--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
recipes_df = recipes_df_chunk.select("chunk_text").withColumnRenamed("chunk_text", "recipe_text")
recipes_df.show()
# Out:
# 25/04/20 19:15:52 WARN TaskSetManager: Stage 7 contains a task of very large size (16301 KiB). The maximum recommended task size is 1000 KiB.
# +--------------------+
# |         recipe_text|
# +--------------------+
# |Baked Greens Chip...|
# |Sweet Potato-Chic...|
# |Cali Burger\n1/4 ...|
# |Oatmeal Cream Che...|
# |Campari Spritzer\...|
# |Seared Rack of La...|
# |Cream Puffs\n6 ta...|
# |Italian Style Hot...|
# |Crab Cakes Salad\...|
# |Hot Cross Buns\n2...|
# |Strawberries with...|
# |Curry Chicken\n2 ...|
# |Golden Squash Blo...|
# |Mexican Hot Choco...|
# |Georgian Short Ri...|
# |Chicken Milanese\...|
# |Citrus Marinated ...|
# |Beet-and-Potato L...|
# |Green Tea and Gin...|
# |Jalapeno Cheese B...|
# +--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Generate Embeddings

# %%
# Load chunked JSON data
with open("chunked_data.json", "r", encoding="utf-8") as f:
    chunked_data = json.load(f)

# load model and generate embeddings
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = np.array([embedding_model.encode(chunk["body"]) for chunk in chunked_data], dtype=np.float32)

# Store embeddings in chunked JSON
for i, chunk in enumerate(chunked_data):
    chunk["embedding"] = embeddings[i].tolist()
    
# Create and save FAISS index
embedding_dim = embeddings.shape[1]
index = faiss.IndexFlatL2(embedding_dim)
index.add(embeddings)

# %% [markdown]
# ### Model Ingestion

# %% [markdown]
# ##### Prompt Engineering
# The prompt inputted by the user should only need to contain the necessary recipe that the user wants to modify. The following prompt engineering code adds additional, consistent language that does the following:
# - Specifies that the user wants to modify the recipe, retaining the original intention
# - Provides the dietary framework to stick to, in this case the high-protein low-carb diet. In another phase of development, this could be changed to xspecify a diet of choice
# - Requests a list of macronutrients based on the data

# %% [markdown]
# ##### RAG Component

# %%
sampled_recipes = (
    recipes_df.sample(withReplacement=False, fraction=0.1, seed=42)
    .select("recipe_text")
    .toLocalIterator()
)
# Out:
# 25/04/20 19:20:40 WARN TaskSetManager: Stage 10 contains a task of very large size (16301 KiB). The maximum recommended task size is 1000 KiB.
# [Stage 10:=====>                                                   (1 + 9) / 10]

# %%
def retrieve_relevant_chunks(query, k=5):
    """Retrieve top-k most relevant chunks using FAISS."""
    query_embedding = embedding_model.encode(query).reshape(1, -1)  # Convert query to embedding
    distances, indices = index.search(query_embedding, k)  # Retrieve top-k chunks

    return [chunked_data[i] for i in indices[0]]  # Get original text chunks

def query_ollama_with_context(query):
    """Retrieve relevant context and query Ollama 3.2."""
    retrieved_chunks = retrieve_relevant_chunks(query)
    context = "\n".join([chunk["body"] for chunk in retrieved_chunks])  # Combine relevant chunks

    # Formulate prompt for LLaMA
    prompt = f"Context:\n{context}\n\nQuery: {query}\nAnswer:"

    # Query Ollama
    response = ollama.chat(model="llama3.2", messages=[{"role": "user", "content": prompt}])
    return response["message"]["content"]

# %%
# if __name__ == "__main__":
#     query = input("Enter your recipe: ")
#     query += " Modify this recipe so that it is more suited for a high-protein, low carb diet. Provide a list of macronutrients as a part of the analysis."
#     answer = query_ollama_with_context(query)
#     print("\nOllama's Answer:", answer)

# %%
sampled_recipes = (
    recipes_df.sample(withReplacement=False, fraction=0.1, seed=42)
    .limit(100)
    .select("recipe_text")
    .toLocalIterator()
)
results = []
for line_num, row in enumerate(sampled_recipes):
    raw_query = row.recipe_text
    query = f"""{raw_query}
    
    Determine whether this recipe is a **solid food dish** that is meant to be eaten (in whole or in part) as a standalone food 
    item — such as a snack, side dish, entrée, breakfast, lunch, or dinner item.
    
    If the recipe is a **non-food item**, or if it is a **drink, cocktail, smoothie, marinade, condiment, dressing, spice mix, sauce, 
    or ingredient prep**, respond with:
    "This recipe is not a solid food dish and does not require modification."  
    Only if the recipe is not a solid food dish **briefly explain why**, and stop. Do **not** modify anything. 
    
    ---
    
    Modify recipes it to fit a **high-protein, low-carbohydrate** dietary pattern using the following:
    
    ### Dietary Goals:
    - Protein: 30–50% of total calories (target ~40%)
    - Fats: 20–40% (target ~30%)
    - Carbohydrates: 10–30% (target ~20%)
    
    ### Substitution Guidelines:
    - Prioritize lean protein sources.
    - Avoid cream, butter, full-fat cheese, fatty meats, or excessive oils.
    - Use low-fat cooking methods (grilling, baking, steaming).
    - Favor vegetables and legumes over starchy carbs.
    - Use cooking spray or broth instead of oil where possible.
    - **Only make substitutions that are likely to still taste good and preserve the appeal of the dish.** Avoid swaps that would make 
    the texture or flavor unpleasant.

    Avoid high-fat ingredients such as:
    - oils (even olive oil or coconut oil)
    - cream, butter, or cheese (unless low-fat versions are used in moderation)
    - fatty meats (like bacon, sausage, ground beef)
    - full-fat dairy
    - avocados, nuts, and seeds (limit to small quantities only if essential)
    
    Use the following **low-fat flavor and texture enhancers** instead:
    - vinegar, lemon juice, mustard, garlic, spices
    - vegetable purées (e.g., carrot, cauliflower, zucchini)
    - low-fat dairy alternatives (e.g., non-fat Greek yogurt, fat-free cottage cheese)
    - broth-based sauces instead of cream sauces

    If fat content exceeds 35%, **revise the recipe to reduce fat** until it falls between 20–35%. 
    
    ---
    
    ### Output Requirements:
    1. Title of Recipe
    2. Explanation of any substitutions made.
    3. Modified ingredient list.
    4. Modified cooking instructions.
    5. Macronutrient breakdown in this format:
       - Protein: #.# g  
       - Fats: #.# g  
       - Carbohydrates: #.# g  
    6. Confirm whether the final recipe meets macro goals. If not, revise it again — but only show the final version.
    Provide only the above. Do not include any additional sections in the output.
    
    Do **not** show failed or intermediate attempts. Just the final, modified version.
    """

    try:
        answer = query_ollama_with_context(query)
        results.append({
            "original_recipe": raw_query,
            "modified_response": answer
        })
        print(f"Completed line {line_num}")
    except Exception as e:
        results.append({
            "original_recipe": raw_query,
            "modified_response": f"Error: {e}"
        })

results_df = spark.createDataFrame([Row(**r) for r in results])
# Out:
# 25/04/20 19:20:41 WARN TaskSetManager: Stage 11 contains a task of very large size (16301 KiB). The maximum recommended task size is 1000 KiB.
# Completed line 0
# Completed line 1
# Completed line 2
# Completed line 3
# Completed line 4
# Completed line 5
# Completed line 6
# Completed line 7
# Completed line 8
# Completed line 9
# Completed line 10
# Completed line 11
# Completed line 12
# Completed line 13
# Completed line 14
# Completed line 15
# Completed line 16
# Completed line 17
# Completed line 18
# Completed line 19
# Completed line 20
# Completed line 21
# Completed line 22
# Completed line 23
# Completed line 24
# Completed line 25
# Completed line 26
# Completed line 27
# Completed line 28
# Completed line 29
# Completed line 30
# Completed line 31
# Completed line 32
# Completed line 33
# Completed line 34
# Completed line 35
# Completed line 36
# Completed line 37
# Completed line 38
# Completed line 39
# Completed line 40
# Completed line 41
# Completed line 42
# Completed line 43
# Completed line 44
# Completed line 45
# Completed line 46
# Completed line 47
# Completed line 48
# Completed line 49
# Completed line 50
# Completed line 51
# Completed line 52
# Completed line 53
# Completed line 54
# Completed line 55
# Completed line 56
# Completed line 57
# Completed line 58
# Completed line 59
# Completed line 60
# Completed line 61
# Completed line 62
# Completed line 63
# Completed line 64
# Completed line 65
# Completed line 66
# Completed line 67
# Completed line 68
# Completed line 69
# Completed line 70
# Completed line 71
# Completed line 72
# Completed line 73
# Completed line 74
# Completed line 75
# Completed line 76
# Completed line 77
# Completed line 78
# Completed line 79
# Completed line 80
# Completed line 81
# Completed line 82
# Completed line 83
# Completed line 84
# Completed line 85
# Completed line 86
# Completed line 87
# Completed line 88
# Completed line 89
# Completed line 90
# Completed line 91
# Completed line 92
# Completed line 93
# Completed line 94
# Completed line 95
# Completed line 96
# Completed line 97
# Completed line 98
# Completed line 99

# %%
results_df.show()
# Out:
# +--------------------+--------------------+
# |     original_recipe|   modified_response|
# +--------------------+--------------------+
# |Italian Style Hot...|Italian Style Hot...|
# |Citrus Marinated ...|Scallop Ceviche\n...|
# |Green Tea and Gin...|Green Tea and Gin...|
# |Spicy Fried Oyste...|Spicy Fried Oyste...|
# |Tres Leches\n2 cu...|Tres Leches Cake\...|
# |Table of Polenta\...|Title of Recipe: ...|
# |Hot Fudge Sauce\n...|Hot Fudge Sauce\n...|
# |Tomato Salsa\n2 r...|Tomato Salsa (Hig...|
# |Raspberry Lemonad...|Raspberry Lemonad...|
# |Peppermint Red Ve...|This recipe is a ...|
# |Chocolate Creme F...|Chocolate Creme F...|
# |Apricot Clafouti\...|Apricot Clafouti ...|
# |Crispy Szechuan-S...|Crispy Szechuan-S...|
# |Dewey's Albuquerq...|Title of Recipe: ...|
# |Sweet-and-Sour Ca...|# Sweet-and-Sour ...|
# |Chocolate Chip Ca...|Chocolate Chip Ca...|
# |Fruity Gum Flower...|Fruity Gum Flower...|
# |Gingerbread House...|Gingerbread House...|
# |Surf and Turf Rib...|Surf and Turf Cro...|
# |Corn Doggies\n2 1...|Title of Recipe\n...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
# 1. Save as a single Parquet file
results_df.coalesce(1).write.parquet("temp_parquet_output", mode="overwrite")

# 2. Move the part file to a final .parquet file
import os
import shutil

temp_folder = "temp_parquet_output"
final_file = "results_output.parquet"

# Find the part file and move it
for fname in os.listdir(temp_folder):
    if fname.startswith("part-") and fname.endswith(".parquet"):
        shutil.move(os.path.join(temp_folder, fname), final_file)
        break

# Optional: clean up
shutil.rmtree(temp_folder)

print(f"✅ DataFrame saved as '{final_file}' in: {os.getcwd()}")
# Out:
# ✅ DataFrame saved as 'results_output.parquet' in: /Users/jenny/ollama-env

# %% [markdown]
# ### Recipe Evaluator

# %%
def extract_macronutrients(recipe_text):
    # Define a regular expression pattern to search for protein, fat, and carbs
    protein_pattern = r"Protein:\s*.*(\d+\.?\d*?)g"
    fat_pattern = r"Fats:\s*.*(\d+\.?\d*?)g"
    carbs_pattern = r"Carbohydrates:\s*.*(\d+\.?\d*?)g"
    
    # Search the text for the respective macronutrients
    protein = re.search(protein_pattern, recipe_text)
    fat = re.search(fat_pattern, recipe_text)
    carbs = re.search(carbs_pattern, recipe_text)
    
    # Extract the values if found
    protein_value = float(protein.group(1)) if protein else None
    fat_value = float(fat.group(1)) if fat else None
    carbs_value = float(carbs.group(1)) if carbs else None
    
    # Return the extracted values
    return {
        "P": protein_value,
        "F": fat_value,
        "C": carbs_value
    }

# %%
from pyspark.sql import functions as f
extract_macronutrients_udf = f.udf(extract_macronutrients, MapType(StringType(), FloatType()))

# %%
def evaluate_recipe(protein_g, fat_g, carb_g):
    # Caloric values per gram
    PROTEIN_CAL = 4
    CARB_CAL = 4
    FAT_CAL = 9

    if protein_g is not None and fat_g is not None and carb_g is not None:
        # Calculate total calories
        total_calories = (protein_g * PROTEIN_CAL) + (fat_g * FAT_CAL) + (carb_g * CARB_CAL)
        
        if total_calories == 0:
            return "Invalid recipe: Total calories cannot be zero."
        
        # Calculate macronutrient percentage
        protein_pct = (protein_g * PROTEIN_CAL / total_calories) * 100
        fat_pct = (fat_g * FAT_CAL / total_calories) * 100
        carb_pct = (carb_g * CARB_CAL / total_calories) * 100
        
        # Define healthy ranges
        protein_range = (30, 50)
        fat_range = (20, 40)
        carb_range = (10, 30)
        
        # Check if recipe meets healthy criteria
        if (protein_range[0] <= protein_pct <= protein_range[1] and
            fat_range[0] <= fat_pct <= fat_range[1] and
            carb_range[0] <= carb_pct <= carb_range[1]):
            return "Meets Criteria"
        else:
            return "Does Not Meet Criteria"
    else: 
        return None
# Example usage
recipe_result = evaluate_recipe(protein_g=35.2, fat_g=14.2, carb_g=12.8)
print(recipe_result)
# Out:
# Meets Criteria

# %%
evaluate_recipe_udf = f.udf(evaluate_recipe, StringType())

# %%
results_df.show()
# Out:
# +--------------------+--------------------+
# |     original_recipe|   modified_response|
# +--------------------+--------------------+
# |Italian Style Hot...|Italian Style Hot...|
# |Citrus Marinated ...|Scallop Ceviche\n...|
# |Green Tea and Gin...|Green Tea and Gin...|
# |Spicy Fried Oyste...|Spicy Fried Oyste...|
# |Tres Leches\n2 cu...|Tres Leches Cake\...|
# |Table of Polenta\...|Title of Recipe: ...|
# |Hot Fudge Sauce\n...|Hot Fudge Sauce\n...|
# |Tomato Salsa\n2 r...|Tomato Salsa (Hig...|
# |Raspberry Lemonad...|Raspberry Lemonad...|
# |Peppermint Red Ve...|This recipe is a ...|
# |Chocolate Creme F...|Chocolate Creme F...|
# |Apricot Clafouti\...|Apricot Clafouti ...|
# |Crispy Szechuan-S...|Crispy Szechuan-S...|
# |Dewey's Albuquerq...|Title of Recipe: ...|
# |Sweet-and-Sour Ca...|# Sweet-and-Sour ...|
# |Chocolate Chip Ca...|Chocolate Chip Ca...|
# |Fruity Gum Flower...|Fruity Gum Flower...|
# |Gingerbread House...|Gingerbread House...|
# |Surf and Turf Rib...|Surf and Turf Cro...|
# |Corn Doggies\n2 1...|Title of Recipe\n...|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
results_evaluated_df = results_df.withColumn("macros", extract_macronutrients_udf(f.col("modified_response")))
results_evaluated_df = results_evaluated_df.withColumn("dietary_compliance", evaluate_recipe_udf(
    f.col("macros").getItem("P"), 
    f.col("macros").getItem("F"), 
    f.col("macros").getItem("C")))

results_evaluated_df = results_evaluated_df.withColumn("protein", f.col("macros").getItem("P"))\
                                            .withColumn("fat", f.col("macros").getItem("F"))\
                                            .withColumn("carbohydrates", f.col("macros").getItem("C"))\
                                            .withColumn("protein_calories", f.col("protein") * 4)\
                                            .withColumn("fat_calories", f.col("fat") * 9)\
                                            .withColumn("carb_calories", f.col("carbohydrates") * 4)\
                                            .withColumn("total_calories", f.col("protein_calories") + f.col("fat_calories") + f.col("carb_calories"))\
                                            .withColumn("percent_protein", f.col("protein_calories") / f.col("total_calories"))\
                                            .withColumn("percent_fat", f.col("fat_calories") / f.col("total_calories"))\
                                            .withColumn("percent_carb", f.col("carb_calories") / f.col("total_calories"))
results_evaluated_df.toPandas()
# Out:
#                                       original_recipe  \
# 0   Italian Style Hot Dogs\nCooking oil, suitable ...
# 1   Citrus Marinated Olives\n1 pound large green o...
# 2   Green Tea and Ginger Granita\n3 cups water\n1/...
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...
# 4   Tres Leches\n2 cups chilled Homemade Sweetened...
# ..                                                ...
# 95  The Way to a Man's Heart\n1 pound halibut ADVE...
# 96  Armenian Rice Pilaf\n1/2 cup butter ADVERTISEM...
# 97  Ham and Chicken Casserole\n1/2 cup uncooked eg...
# 98  Cannoli\n1 cup confectioners' sugar ADVERTISEM...
# 99  It Won't Last Cake\n1 1/3 cups vegetable oil A...
#
#                                     modified_response  \
# 0   Italian Style Hot Dogs\n\nThis recipe is a sol...
# 1   Scallop Ceviche\n\nThis recipe is a solid food...
# 2   Green Tea and Ginger Granita\n\nThis recipe is...
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...
# 4   Tres Leches Cake\n\nThis recipe is a solid foo...
# ..                                                ...
# 95  The Way to a Man's Heart\n\nThis recipe is not...
# 96  Armenian Rice Pilaf\n\nThis recipe is a solid ...
# 97  Ham and Chicken Casserole\nThis recipe is a so...
# 98  # Cannoli\n\nThis recipe is a solid food dish ...
# 99  It Won't Last Cake\n\nThis recipe is a solid f...
#
#                                macros      dietary_compliance  protein  fat  \
# 0      {'P': 2.0, 'F': 8.0, 'C': 1.0}  Does Not Meet Criteria      2.0  8.0
# 1      {'P': 8.0, 'F': 5.0, 'C': 7.0}  Does Not Meet Criteria      8.0  5.0
# 2   {'P': None, 'F': None, 'C': None}                    None      NaN  NaN
# 3      {'P': 5.0, 'F': 5.0, 'C': 2.0}  Does Not Meet Criteria      5.0  5.0
# 4      {'P': 5.0, 'F': 5.0, 'C': 0.0}  Does Not Meet Criteria      5.0  5.0
# ..                                ...                     ...      ...  ...
# 95     {'P': 2.0, 'F': 1.0, 'C': 7.0}  Does Not Meet Criteria      2.0  1.0
# 96  {'P': None, 'F': None, 'C': None}                    None      NaN  NaN
# 97  {'P': None, 'F': None, 'C': None}                    None      NaN  NaN
# 98  {'P': None, 'F': None, 'C': None}                    None      NaN  NaN
# 99  {'P': None, 'F': None, 'C': None}                    None      NaN  NaN
#
#     carbohydrates  protein_calories  fat_calories  carb_calories  \
# 0             1.0               8.0          72.0            4.0
# 1             7.0              32.0          45.0           28.0
# 2             NaN               NaN           NaN            NaN
# 3             2.0              20.0          45.0            8.0
# 4             0.0              20.0          45.0            0.0
# ..            ...               ...           ...            ...
# 95            7.0               8.0           9.0           28.0
# 96            NaN               NaN           NaN            NaN
# 97            NaN               NaN           NaN            NaN
# 98            NaN               NaN           NaN            NaN
# 99            NaN               NaN           NaN            NaN
#
#     total_calories  percent_protein  percent_fat  percent_carb
# 0             84.0         0.095238     0.857143      0.047619
# 1            105.0         0.304762     0.428571      0.266667
# 2              NaN              NaN          NaN           NaN
# 3             73.0         0.273973     0.616438      0.109589
# 4             65.0         0.307692     0.692308      0.000000
# ..             ...              ...          ...           ...
# 95            45.0         0.177778     0.200000      0.622222
# 96             NaN              NaN          NaN           NaN
# 97             NaN              NaN          NaN           NaN
# 98             NaN              NaN          NaN           NaN
# 99             NaN              NaN          NaN           NaN
#
# [100 rows x 14 columns]

# %%
results_evaluated_df.groupBy("dietary_compliance").count().show()
# Out:
# +--------------------+-----+
# |  dietary_compliance|count|
# +--------------------+-----+
# |                NULL|   44|
# |Does Not Meet Cri...|   53|
# |      Meets Criteria|    3|
# +--------------------+-----+

# %%
results_evaluated_df.select("percent_protein").filter(results_evaluated_df["percent_protein"].isNotNull()).orderBy("percent_protein", ascending=False).show()
# Out:
# +-------------------+
# |    percent_protein|
# +-------------------+
# |                1.0|
# | 0.5405405405405406|
# | 0.5245901639344263|
# |                0.5|
# | 0.4878048780487805|
# |0.48484848484848486|
# |0.47619047619047616|
# |0.47058823529411764|
# |0.41379310344827586|
# |0.40816326530612246|
# | 0.3870967741935484|
# | 0.3764705882352941|
# |0.36363636363636365|
# |0.36363636363636365|
# | 0.3333333333333333|
# |0.32727272727272727|
# | 0.3076923076923077|
# | 0.3047619047619048|
# | 0.2857142857142857|
# | 0.2857142857142857|
# +-------------------+
# only showing top 20 rows

# %%
calorie_stats_df = results_evaluated_df.select("protein", "percent_protein", 
                                       "fat", "percent_fat",
                                       "carbohydrates", "percent_carb", 
                                       "total_calories")
calorie_stats_df.summary().toPandas()
# Out:
# 25/04/20 19:44:28 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
#   summary             protein      percent_protein                 fat  \
# 0   count                  57                   56                  57
# 1    mean   3.789473684210526  0.25753304385399123   4.157894736842105
# 2  stddev  2.1442351458975426   0.1703173145936162  2.5966288150229557
# 3     min                 0.0                  0.0                 0.0
# 4     25%                 2.0  0.14035087719298245                 2.0
# 5     50%                 3.0  0.21621621621621623                 4.0
# 6     75%                 5.0   0.3333333333333333                 6.0
# 7     max                 9.0                  1.0                 9.0
#
#            percent_fat       carbohydrates         percent_carb  \
# 0                   56                  57                   56
# 1   0.5250887945376266  3.3333333333333335  0.21737816160838216
# 2  0.25246838180770614    2.70801280154532  0.18532856438133957
# 3                  0.0                 0.0                  0.0
# 4   0.2903225806451613                 1.0  0.06060606060606061
# 5   0.5294117647058824                 2.0  0.16666666666666666
# 6   0.7241379310344828                 5.0  0.32786885245901637
# 7                  1.0                 9.0   0.6666666666666666
#
#        total_calories
# 0                  56
# 1   65.51785714285714
# 2  25.336277312421963
# 3                16.0
# 4                44.0
# 5                65.0
# 6                84.0
# 7               125.0

# %%
for num, answer in enumerate(results_df.select("modified_response").collect()): 
    print(f"--------------------------------------{num}---------------------------------------------")
    print(answer.modified_response[:500])
# Out:
# --------------------------------------0---------------------------------------------
# Italian Style Hot Dogs
#
# This recipe is a solid food dish and does not require modification.
#
# ### Modified Ingredient List:
# - 2 medium potatoes
# - 4 all-beef hot dogs
# - 1 medium onion
# - 1 green or red pepper
# - 1 medium round loaf of Italian bread
# - Mustard
# - Ketchup
# - Red pepper flakes
#
# ### Modified Cooking Instructions:
# In a saucepan over medium-high heat, heat enough cooking spray to cover the potatoes to frying temperature (325 to 350 degrees F), and add the potato rounds. Turn them over when t
# --------------------------------------1---------------------------------------------
# Scallop Ceviche
#
# This recipe is a solid food dish and does not require modification.
#
# Title of Recipe: Modified Citrus Marinated Olives
#
# Explanation of Substitutions:
# - No substitutions were made to this recipe.
#
# Modified Ingredient List:
#
# 1 pound large green olives with pits
# 1 clove garlic, minced
# 1/2 cup low-fat extra-virgin olive oil (reduced from 1/2 cup regular olive oil)
# 1 tablespoon red wine vinegar
# 1 lemon, zested and juiced
# 1/2 teaspoon dried red pepper flakes
# 1/2 teaspoon dried tarrago
# --------------------------------------2---------------------------------------------
# Green Tea and Ginger Granita
#
# This recipe is a non-food item, specifically a drink, as it's meant to be served immediately after freezing and doesn't require modification.
#
# Modified ingredient list:
# - 3 cups water
# - 1/4 cup sugar-free sweetener (e.g., stevia or erythritol)
# - 1 (1-inch) piece fresh ginger, peeled and sliced
# - 4 green tea bags
# - Juice of 2 oranges
# - Ice cubes
#
# Modified cooking instructions:
# 1. Bring a tea kettle with 3 cups of water to a boil over medium heat.
# 2. In a heatproof bo
# --------------------------------------3---------------------------------------------
# Spicy Fried Oysters on Jalapeno Caesar Salad
#
# This recipe is a solid food dish that can be eaten as a standalone meal item, such as an entrée or appetizer.
#
# Modified ingredient list:
# - 16 medium-large fresh oysters
# - 2 cups dried cornbread crumbs (substituted with low-carb almond flour)
# - 1 serrano chili, seeded and finely chopped
# - 1 clove garlic, finely chopped
# - 1 teaspoon cayenne pepper
# - 1 teaspoon ground black pepper
# - 3/4 cup canola oil (reduced to 1/2 cup) (substituted with avocado oil)
#
# --------------------------------------4---------------------------------------------
# Tres Leches Cake
#
# This recipe is a solid food dish that is meant to be eaten as a standalone dessert item.
#
# Modified Recipe:
#
# Title of Recipe: High-Protein Tres Leches Cake
#
# Explanation of Substitutions:
# To modify this recipe to fit a high-protein, low-carbohydrate dietary pattern, the following substitutions were made:
#
# * Replaced granulated sugar with natural sweeteners like stevia and erythritol
# * Used almond flour instead of cake flour to reduce carbohydrate content
# * Swapped whole milk with
# --------------------------------------5---------------------------------------------
# Title of Recipe: Balsamic Vegetable Grill with Poached Sausages
#
# Explanation of Substitutions:
# To meet the high-protein, low-carbohydrate dietary pattern, modifications were made to reduce fat content and increase protein sources.
#
# Modified Ingredient List:
#
# * 4 oz sausages (replaced full-fat sausage)
# * 1/2 cup cherry tomatoes
# * 1/2 cup bell peppers (reduced amount of onions)
# * 2 cloves garlic
# * 2 tbsp balsamic vinegar
# * 1 tsp olive oil spray
# * Salt and pepper to taste
# * Fresh basil for garnish
#
# --------------------------------------6---------------------------------------------
# Hot Fudge Sauce
# This recipe is a non-food item, or specifically, it is intended to be used as a condiment. The instructions instruct readers to "store in the refrigerator" and "reheat in a saucepan over medium-low heat," which suggests that the hot fudge sauce will be used to top other foods, such as ice cream.
#
# Modified Recipe:
#
# Title of Recipe: Low-Fat Hot Fudge Sauce
#
# Explanation of Substitutions: The original recipe was modified by removing all high-fat ingredients and replacing them with lo
# --------------------------------------7---------------------------------------------
# Tomato Salsa (High-Protein, Low-Carb Version)
#
# No explanation is needed as this recipe is a solid food dish meant to be eaten as a standalone item — such as a snack or side dish.
#
# ### Dietary Goals:
# - Protein: 40% of total calories
# - Fats: 30% of total calories
# - Carbohydrates: 20% of total calories
#
# ### Substitution Guidelines:
# - Replaced full-fat vinaigrette with low-fat Greek yogurt for a creamier texture without added fat.
#
# ### Modified Ingredient List:
# 2 ripe tomatoes, cored and seeded and
# --------------------------------------8---------------------------------------------
# Raspberry Lemonade Recipe
#
# This recipe is a drink.
#
# Ingredient List:
# - 3/4 cup fresh or thawed frozen raspberries
# - 9 cups water
# - 2 cups freshly squeezed lemon juice (about 12 lemons)
# - 2 cups superfine sugar
# Modified Ingredient List:
# - 3/4 cup fresh or thawed frozen raspberries
# - 9 cups water
# - 2 cups freshly squeezed lemon juice (about 12 lemons)
# - 1.5 cups stevia or erythritol sweetener
# - 1 cup unsweetened almond milk
#
# Modified Cooking Instructions:
# - Combine the raspberry puree, water, an
# --------------------------------------9---------------------------------------------
# This recipe is a solid food dish and does not require modification. It is intended to be eaten as a standalone food item.
# --------------------------------------10---------------------------------------------
# Chocolate Creme Fraiche Pot
#
# This recipe is a solid food dish meant to be eaten as a standalone dessert item — such as a snack or dessert item.
#
# ---
#
# Modified Recipe:
#
# Title of Recipe: Chocolate Creme Fraiche Low-Carb Delight
#
# Explanation of Substitutions:
# To modify the recipe to fit a high-protein, low-carbohydrate dietary pattern, I replaced traditional whipped cream with non-fat Greek yogurt to reduce fat content and calories. Additionally, I used semisweet chocolate instead of milk chocolate
# --------------------------------------11---------------------------------------------
# Apricot Clafouti (High-Protein, Low-Carbohydrate Version)
#
# Substitutions made to fit a high-protein, low-carbohydrate dietary pattern:
#
# * Used egg whites and reduced sugar content to decrease carbohydrate intake
# * Replaced heavy cream with non-fat Greek yogurt for added protein
#
# Modified ingredient list:
# - 2 large eggs, separated
# - 1/6 cup (15g) granulated sweetener (e.g., Swerve or Erythritol)
# - 3 tablespoons all-purpose flour
# - 1/2 cup non-fat Greek yogurt
# - 1 teaspoon vanilla extract
# - ¼ teas
# --------------------------------------12---------------------------------------------
# Crispy Szechuan-Style Eggplant and Tofu with Gravy
#
# This recipe is a **solid food dish** that can be eaten as a standalone entrée item.
#
# To modify the recipe to fit a high-protein, low-carbohydrate dietary pattern:
#
# Substitutions made:
# - Replaced heavy cream with chicken stock
# - Used peanut oil instead of vegetable oil for frying
# - Removed mozzarella cheese and added brie instead in smaller amount
# - Added turmeric powder, chilli powder, and garam masala to enhance flavor without adding extra car
# --------------------------------------13---------------------------------------------
# Title of Recipe: Dewey's Albuquerque Coleslaw
#
# Explanation of substitutions made:
#
# - Replaced sweet onions with roasted garlic and green chilies to reduce carbohydrate content and increase protein and fiber.
# - Reduced amount of olive oil from 1/4 cup to 2 tablespoons to decrease fat content.
# - Used chopped cilantro instead of a large bunch for reduced carbohydrate intake.
#
# Modified ingredient list:
# 2 bags (14 ounces) shredded coleslaw mix
# 2 tablespoons green chile spice rub
# 2 teaspoons sugar
# Jui
# --------------------------------------14---------------------------------------------
# # Sweet-and-Sour Cabbage with Balsamic Vinegar
#
# This recipe is a solid food dish that can be eaten as a standalone side item.
#
# ### Modified Ingredient List:
# - 2 onions
# - 1/4 pound sliced prosciutto (use leaner options like turkey or chicken ham)
# - 6 garlic cloves
# - 5 1/2-inch dried chilies
# - 7 tablespoons olive oil (reduce to 3 tablespoons and use cooking spray when possible)
# - 1 1/2 pounds Savoy cabbage
# - 1 tablespoon sugar (reduce to 1 teaspoon for a sweeter taste without excessive carbs)
# - 6
# --------------------------------------15---------------------------------------------
# Chocolate Chip Caramel Bars
# This recipe is a solid food dish and does require modification to fit a high-protein, low-carbohydrate dietary pattern.
#
# ### Dietary Goals:
# - Protein: 30–50% of total calories (target ~40%)
# - Fats: 20–40% (target ~30%)
# - Carbohydrates: 10–30% (target ~20%)
#
# ### Substitution Guidelines:
# Prioritize lean protein sources. Avoid cream, butter, full-fat cheese, fatty meats, or excessive oils.
#
# ### Modified Recipe:
#
# 1 cup Crisco Light Butter Flavor All-Vegetable Shortening
# 1
# --------------------------------------16---------------------------------------------
# Fruity Gum Flower
#
# This recipe is a non-food item, as it appears to be an edible decoration or garnish for a cupcake rather than a standalone food dish.
# --------------------------------------17---------------------------------------------
# Gingerbread House
# -----------------
#
# This recipe is a solid food dish and does not require modification.
#
# Modified Recipe:
# ----------------
#
# Title of Recipe: Gingerbread House (Low-Carb Version)
#
# Explanation of Substitutions:
# The following substitutions were made to reduce carbohydrates and increase protein:
#
# - Baking soda -> baking powder (to maintain structural integrity)
# - Honey dough added extra carbs, replaced with almond flour to reduce carb content
# - Canola oil used in cooking method inst
# --------------------------------------18---------------------------------------------
# Surf and Turf Crostini
#
# This recipe is a solid food dish that is meant to be eaten as a standalone appetizer or entrée item.
#
# Modified Recipe:
#
# Title of Recipe: Surf and Turf Crostini (Low-Carb Version)
#
# Explanation of Substitutions:
# - Baguette slices were toasted with salt and pepper only, skipping the butter for a lower-carb version.
# - The Gorgonzola mousse was made with low-fat cream cheese to reduce fat content.
# - A portion of the Caramelized Bourbon Shallots was omitted due to high carb con
# --------------------------------------19---------------------------------------------
# Title of Recipe
# Corn Doggies (Modified for High-Protein, Low-Carbohydrate Diet)
#
# Explanation of Substitutions:
# To make this recipe suitable for a high-protein, low-carbohydrate diet, I replaced the canola oil with cooking spray to reduce fat content. Additionally, I removed the Parmesan cheese and used low-fat dairy alternatives instead.
#
# Modified Ingredient List:
#
# * 2 1/2 cups all-purpose flour (unchanged)
# * 3 cups cornmeal (unchanged)
# * 1 1/2 teaspoons baking soda (unchanged)
# * 1 1/2 teaspoons
# --------------------------------------20---------------------------------------------
# Tie-Dye Cookies (Modified for High-Protein, Low-Carbohydrate Diet)
#
# Explanation of substitutions made:
#
# - Store-bought vanilla frosting was replaced with a homemade alternative to reduce fat content and increase protein.
#
# Modified ingredient list:
#
# * 12 store-bought sugar cookies
# * 2 cups (250g) plain non-fat Greek yogurt
# * 1 cup (120g) unsalted butter, softened
# * 2 teaspoons (10g) vanilla extract
# * 3 different food-coloring gels of your choice
#
# Modified cooking instructions:
#
# 1. Scoop the dough
# --------------------------------------21---------------------------------------------
# Title of Recipe: High-Protein Double Decker Burger
#
# Explanation of Substitutions:
# Due to its high fat and carbohydrate content, this recipe has been modified to meet the high-protein, low-carbohydrate dietary pattern.
#
# Modified Ingredient List:
#
# - 1/4 cup nonfat plain Greek yogurt (replacing sour cream)
# - 2 tablespoons Dijon mustard (replacing horseradish)
# - Salt, a pinch
# - White pepper, a pinch
# - 1/2 cup shredded iceberg lettuce
# - 1/2 cup low-carb ketchup (replacing regular ketchup)
# - 1 teaspoo
# --------------------------------------22---------------------------------------------
# Title of Recipe: Bacon and Greens
# Explanation of Substitutions:
# No modifications were made to this recipe as it is a non-food item, specifically a cooking technique for rendering bacon fat and sautéing greens.
#
# Modified Ingredient List:
#
# - 0g) diced carrots, ¹/₃ cup (50g) diced onions (half a small onion), and 1 bay leaf or 1 sprig of thyme.
#
# Modified Cooking Instructions:
# 1. Cook to soften and lightly brown, about 5 minutes, and then add 2 tablespoons (18g) flour and continue cooking the mixtu
# --------------------------------------23---------------------------------------------
# Parsnips with Bacon
#
# Explanation of substitutions made:
# - No significant changes were needed to balance macros while maintaining flavor and appeal.
#
# Modified ingredient list:
# - 2 strips chopped thick-cut bacon
# - 1 thinly sliced onion
# - 1 pound parsnips (peeled and cut into 2-inch pieces)
# - 2 sliced celery stalks
# - Salt and pepper
# - Vegetable oil
# - 1 1/2 cups chicken broth
#
# Modified cooking instructions:
# 1. Cook 2 strips chopped thick-cut bacon in vegetable oil over medium-high heat until almost
# --------------------------------------24---------------------------------------------
# Melon Fettuccini with Sweet Wine and Fresh Mint (Modified)
#
# This recipe is a solid food dish and does require modification to fit a high-protein, low-carbohydrate dietary pattern.
#
# ### Dietary Goals:
# - Protein: 30–50% of total calories (target ~40%)
# - Fats: 20–40% (target ~30%)
# - Carbohydrates: 10–30% (target ~20%)
#
# ### Substitution Guidelines:
#
# Prioritize lean protein sources, avoid cream, butter, full-fat cheese, fatty meats, or excessive oils. Use low-fat cooking methods and favor vegetables
# --------------------------------------25---------------------------------------------
# Aromatic Braised Oxtail with Preserved Lemon Polenta
#
# Explanation of substitutions:
# - Dark soy sauce has been removed to reduce carbohydrate content and fat is being incorporated from vegetable purées.
#
# Modified ingredient list:
#
# * 12 oxtails
# * 2 cups mixed vegetables (such as carrot, cauliflower)
# * 1/4 cup ancho chile powder
# * 1/4 cup salt
# * 1/8 cup black pepper
# * 2 chopped onions
# * 2 chopped fennel
# * 1/2 stalk chopped celery
# * 1 large chopped carrot
# * 10 garlic cloves
# * 1 tablespoon minced gi
# --------------------------------------26---------------------------------------------
# Turkey and Corn Meatballs with Roasted Pepper Sauce
#
# This recipe is a solid food dish that is meant to be eaten (in whole or in part) as a standalone food item — specifically, an entrée.
#
# 1. This recipe is not a solid food dish and does not require modification.
#
# 2.
# To modify the recipe for a high-protein, low-carbohydrate dietary pattern:
#
# Substitutions made:
# - The original recipe used ground turkey breast and dark meat. No changes were necessary as they are both lean protein sources.
# - Corn k
# --------------------------------------27---------------------------------------------
# Smoked Gouda Grits (Modified)
#
# Explanation of substitutions made:
# - Replaced half-and-half with water to reduce fat content and make the dish lower in calories.
# - Removed butter from the original recipe as it is high in fat.
#
# Modified ingredient list:
# - 1 package quick-cooking grits
# - 1 cup grated smoked Gouda, plus more to taste (no change)
# - Half-and-half (replaced with water) (no change)
# - Pat butter (removed)
# - Sea salt and pepper (no change)
#
# Modified cooking instructions:
# 1. Prepare grits
# --------------------------------------28---------------------------------------------
# Pineapple-Rum Mustard
# This recipe is a condiment.
#
# Modified ingredient list:
# - 2 tablespoons yellow mustard seeds
# - 1 tablespoon brown mustard seeds
# - 1 1/2 tablespoons mustard powder
# - 1/4 cup crushed fresh pineapple
# - 1 teaspoon stripped fresh thyme
# - Salt and a small pinch dried Scotch Bonnet chile, or to taste
# - 2 teaspoons vinegar (replaced demerara sugar)
# - 6 tablespoons dark rum
#
# Modified cooking instructions:
# Grind the mustard seeds in a mortar and pestle or a spice mill. Place the groun
# --------------------------------------29---------------------------------------------
# Couscous Carnivale
# This recipe is a solid food dish and does not require modification.
#
# Modified ingredient list:
# - 1 1/2 cups lean couscous (substituted with whole wheat couscous)
# - 1/4 teaspoon salt
# - 3/4 cup low-sodium chicken stock
# - 3/4 cup unsweetened apple juice
# - 1 mango, diced small
# - 1 Granny Smith apple, cored and diced small
# - 1 small red pepper, diced small
# - 1 small yellow pepper, diced small
# - 4 spring onions, thinly sliced including green tops
# - 1/2 cup dried cranberries (substit
# --------------------------------------30---------------------------------------------
# # High-Protein, Low-Carb Version of 3 Bean Salad and Potato Salad with Sweet Red Pepper and Onion
#
# Substitutions made:
#
# * Removed red kidney beans due to high carbohydrate content
# * Replaced with cannellini beans for added protein and fiber
# * Used less amount of olive oil and added more vinegar for dressing
# * Chopped fresh herbs (mint, parsley) instead of dried varieties for better flavor and texture
#
# **Modified Ingredient List:**
#
# - 16 new red potatoes
# - Coarse salt, for boiling water
# - 1 red b
# --------------------------------------31---------------------------------------------
# Spaghetti Sauce
# This recipe is a solid food dish and does not require modification.
#
# Modified ingredient list:
# - 5 pounds ground beef (I used ground round)
# - 3 tablespoons olive oil -> replaced with 1 tablespoon avocado oil to reduce fat content
# - 2 large yellow onions, diced
# - 6 cloves garlic, minced
# - Two 28-ounce cans crushed tomatoes
# - One 14-ounce can crushed tomatoes
# - One 6-ounce can tomato paste
# - 1 jar good store-bought marinara sauce (you can use another jar if you like the sauce to b
# --------------------------------------32---------------------------------------------
# Almond Panna Cotta with Cherry Compote
#
# This recipe is a solid food dish and does not require modification.
#
# Modified Ingredient List:
# - 2 teaspoons unflavored gelatin
# - 1 cup almond milk
# - 2 cups heavy whipping cream (replace with low-fat whipped cream, e.g., 1/4 cup Greek yogurt + 3/4 cup water or non-fat milk)
# - 1/2 cup sugar (reduce to 0.5 cup)
# - 1 pound fresh Bing cherries, pitted
# - 1/3 cup cherry preserves
# - 3 tablespoons balsamic vinegar
#
# Modified Cooking Instructions:
# 1. In a mixing bow
# --------------------------------------33---------------------------------------------
# Spicy Margarita with Jalapeno and Ginger
# This recipe is a drink, cocktail.
# --------------------------------------34---------------------------------------------
# Title of Recipe: Black Bean, Lentil and Eggplant Chili
#
# Explanation of substitutions made:
# - Replaced the diced onion with thinly sliced red onion to reduce carbohydrate content.
# - Used Kosher salt instead of plain salt to reduce sodium content.
#
# Modified ingredient list:
# 1/2 pound dried black beans, picked through
# 4 dried pasilla chiles or New Mexico chile peppers, stemmed (remove seeds for less heat)
# 3 bay leaves
# 4 large cloves garlic, diced
# 3 dried cascabel or guajillo chile peppers, stemmed
# --------------------------------------35---------------------------------------------
# Boozy Bourbon Chicken Marinade (Modified)
#
# Explanation of substitutions made:
# To fit a high-protein, low-carbohydrate dietary pattern, this recipe has been modified to prioritize lean protein sources and reduce fat content.
#
# Modified ingredient list:
#
# * 1/2 cup bourbon
# * 1/4 cup canola oil → replaced with cooking spray
# * 3 tablespoons Dijon mustard (no change)
# * 2 tablespoons Worcestershire sauce (no change)
# * 2 tablespoons brown sugar → reduced to 1 tablespoon to minimize carb content
# * Kosher
# --------------------------------------36---------------------------------------------
# # High-Protein Roasted Vegetables
# This recipe has been modified to fit a high-protein, low-carbohydrate dietary pattern.
#
# Explanation of substitutions:
# - Extra-virgin olive oil was substituted with vegetable purées (e.g., carrot) and broth-based sauces to reduce fat content.
# - Mushrooms were added to increase protein content without increasing carbohydrate content.
# - Asparagus was used in its whole form instead of asparagus puree or juice to maintain fiber and nutrient content.
#
# Modified ingredi
# --------------------------------------37---------------------------------------------
# **Japchae (Vegetarian Korean Noodles) - Modified for High-Protein, Low-Carbohydrate Diet**
#
# Explanation of substitutions made:
# To achieve a high-protein, low-carbohydrate diet, modifications were made to reduce carbohydrate content and increase protein intake. The recipe was adjusted to use vegetable purées as a primary source of starch, reducing the need for noodles. Protein-rich vegetables like kale and oyster mushrooms were incorporated, while starchy ingredients like sweet potato vermicelli
# --------------------------------------38---------------------------------------------
# Neapolitan Pizza (Low-Carb Version)
#
# This recipe is a solid food dish meant to be eaten as an entrée.
#
# ### Modified Ingredient List:
# - 8 ounces water
# - 1/16-ounce yeast
# - 1/4-ounce salt
# - 1 pound bread flour
# - 2 tablespoons olive oil spray
# - 2 tablespoons unsalted butter, melted
# - 2 ounces lean ham or turkey (replacing bacon)
# - 1 onion, diced
# - 2 cloves garlic, minced
# - 16 ounces crushed plum tomatoes
# - 4 ounces low-fat tomato puree
# - 8 ounces low-sodium beef broth
# - 1 bay leaf
# - Pinch thyme
# - ½
# --------------------------------------39---------------------------------------------
# Title of Recipe: Hummus with Sesame (Modified)
#
# Explanation of Substitutions: None necessary; all ingredients are within the recommended dietary goals.
#
# Modified Ingredient List:
# - 1 can garbanzo beans
# - 2 tablespoons lemon juice
# - 2 tablespoons tahini paste
# - 0.25 teaspoon cumin
# - 0.5 clove garlic
# - 1 tablespoon olive oil
# - 1 tablespoon sesame oil
# - Kosher salt and freshly cracked black pepper
# - 0.5 teaspoon smoked paprika
#
# Modified Cooking Instructions:
# 1. Combine the beans, lemon juice, tahin
# --------------------------------------40---------------------------------------------
# Fleur de Sel Melon Soup with Chamomile Sorbet (Modified)
#
# This recipe is a solid food dish and does not require modification.
#
# Title of Recipe
# Fleur de Sel Melon Soup with Chamomile Sorbet
#
# Explanation of Substitutions Made:
# No substitutions were made to this recipe, as it already follows the guidelines for high-protein, low-carbohydrate dietary pattern.
#
# Modified Ingredient List:
# - 3 ripe cantaloupes (no changes)
# - 1 1/2 cups water (no changes)
# - 1/4 cup sugar (reduced from 1/2 cup to meet carb
# --------------------------------------41---------------------------------------------
# Curried Egg Salad (Modified for High-Protein, Low-Carbohydrate Diet)
#
# Explanation of substitutions made: Replaced full-fat yogurt with nonfat Greek yogurt and omitted raisins to reduce carbohydrate content.
#
# 1. 4 large eggs
# 2. 2 cups small new potatoes (about 10)
# 3. 1 small garlic clove, grated
# 4. 1 tablespoon grated peeled fresh ginger
# 5. 2 tablespoons minced fresh cilantro
# 6. 1 tablespoon fresh lemon juice
# 7. 2 teaspoons honey
# 8. 2 teaspoons Dijon mustard
# 9. 2/3 cup nonfat Greek yogurt
# 10. 1 t
# --------------------------------------42---------------------------------------------
# Pear Upside Down Cake
#
# This recipe is a solid food dish meant to be eaten as a standalone dessert item.
#
# Modified Recipe:
#
# Title of Recipe: Pear Upside Down Cake (Low-Carb Version)
#
# Explanation of Substitutions:
# Substitutions were made to reduce the carbohydrate content while maintaining the flavor and texture of the original recipe. The main changes included replacing brown sugar with a low-carb alternative, using almond flour instead of pastry flour, and reducing the amount of sugar used in th
# --------------------------------------43---------------------------------------------
# Peas and Pasta Salad
# This recipe is a solid food dish that is meant to be eaten as a standalone side dish item.
#
# Modified ingredient list:
#
# - 1 pound cavatappi pasta (no changes)
# - Kosher salt and freshly ground black pepper (no changes)
# - 1/4 cup finely chopped red onion (no changes)
# - 1 (15-ounce) jar salad dressing (recommended: Miracle Whip, reduced from 2 tablespoons to 1 tablespoon due to high sugar content)
# - 1 tablespoon apple cider vinegar (reduced from 2 tablespoons to maintain balance
# --------------------------------------44---------------------------------------------
# Turkey Cobb Salad
# No modifications were needed for this recipe as it already falls within the high-protein, low-carbohydrate dietary pattern guidelines.
#
# - Protein: 4 x 6g = 24 g
# - Fats: 3 tablespoons (45 mL) olive oil + 1/2 avocado = 14 g
# - Carbohydrates: 1 pint cherry tomatoes + 2 romaine lettuce hearts + 1/2 avocado = 16 g
#
# The final recipe meets the macro goals.
# --------------------------------------45---------------------------------------------
# Inside-Out Peanut Butter Cookie Cups
#
# This recipe is a solid food dish that can be eaten as a standalone snack item.
#
# Modified Recipe:
# Title of Recipe: Inside-Out Peanut Butter Cookie Cups (High-Protein, Low-Carbohydrate Version)
#
# Explanation of Substitutions:
#
# * Brown sugar was replaced with granulated sweetener to reduce carbohydrates.
# * Milk was reduced to 1 tablespoon to decrease calories and carbohydrates.
# * Semi-sweet chocolate chips were used in moderation, but their carb content is relat
# --------------------------------------46---------------------------------------------
# Almond Bar Cookies
#
# This recipe is a solid food dish and does not require modification for consumption.
#
# ---
#
# High-Protein, Low-Carbohydrate Almond Bar Cookies
#
# ### Dietary Goals:
# - Protein: 30–50% of total calories (target ~40%)
# - Fats: 20–40% (target ~30%)
# - Carbohydrates: 10–30% (target ~20%)
#
# ### Substitution Guidelines:
# To fit a high-protein, low-carbohydrate dietary pattern:
#
# * Replace sugar with natural sweeteners like stevia or erythritol.
# * Use unsweetened almond milk and reduce sugar c
# --------------------------------------47---------------------------------------------
# Title of Recipe
# Rice with Beet Juice (Modified for High-Protein, Low-Carbohydrate)
#
# Explanation of Substitutions:
# Substitutions were made to reduce carbohydrate content and increase protein while maintaining a balanced flavor profile. Specifically, low-fat dairy alternatives and vegetable purées replaced high-carbohydrate ingredients like cream and butter.
#
# Modified Ingredient List:
# - 2 beets
# - 1/2 teaspoon sugar
# - 4 cups chicken stock (low-sodium)
# - 6 tablespoons non-fat Greek yogurt (replacing
# --------------------------------------48---------------------------------------------
# This recipe is a drink, cocktail.
# --------------------------------------49---------------------------------------------
# Grapefruit Pie (Modified for High-Protein, Low-Carb)
#
# Explanation of substitutions made:
# To adapt this recipe to a high-protein, low-carb dietary pattern, I replaced the traditional crust with a baked pie shell and removed the whipped cream topping. Instead, I used a non-fat Greek yogurt-based topping.
#
# Modified ingredient list:
#
# - 1 cup sugar
# - 3 tablespoons cornstarch
# - 1 1/2 cups water
# - 1 (3-ounce) box strawberry gelatin
# - 2 large red grapefruit, sectioned
# - 1 prebaked pie shell
# - 1/4 cup no
# --------------------------------------50---------------------------------------------
# Pasta With Swordfish and Cherry Tomato Sauce (Modified)
#
# This recipe is a solid food dish and can be eaten as an entrée.
#
# To modify this recipe to fit a high-protein, low-carbohydrate dietary pattern:
#
# * Swapped heavy cream with cherry tomato sauce to reduce fat content.
# * Replaced pine nuts with toasted almonds to reduce fat and increase protein.
# * Added fresh parsley to provide extra fiber and antioxidants without adding calories.
#
# Modified ingredient list:
# - 1 pound (1"-thick) swordfish steak
# --------------------------------------51---------------------------------------------
# Cocoa Krispies Treats
#
# This recipe is a solid food dish and does not require modification.
#
# Modified Recipe:
#
# * 3 tablespoons low-fat margarine
# * 1 package (10 oz., about 40) regular marshmallows
# * OR - 4 cups miniature marshmallows
# * 6 cups COCOA KRISPIES cereal
#
# Modified Cooking Instructions:
# In large saucepan melt margarine over low heat. Add marshmallows and stir until completely melted. Remove from heat.
# Add KELLOGG'S COCOA KRISPIES cereal. Stir until well coated.
# Using buttered spatula or
# --------------------------------------52---------------------------------------------
# Poached Oysters in Champagne with a Julienne of Vegetables, Leaf Spinach and Prosciutto Ham
#
# This recipe is not a solid food dish and does not require modification as it contains ingredients intended to be served separately (oysters, vegetables, spinach, prosciutto).
# --------------------------------------53---------------------------------------------
# Title of Recipe: Marshmallow Braids
#
# Explanation of Substitutions Made:
# This recipe is a non-food item as it's meant to be used for decoration purposes only.
#
# Modified Ingredient List:
#
# 1 cup plus 2 tablespoon water
# 2 3/4 cups sugar sugar
# 2/3 cup corn syrup
# 1/3 cup minus 1 tablespoon gelatin powder
# 3/4 cup low-fat broth instead of corn syrup
# 1 fresh lemon, juiced
# 3 different flavored oils (any flavor)
# 3 different colors of food color paste
#
# Modified Cooking Instructions:
# Lightly spray vegetable
# --------------------------------------54---------------------------------------------
# Title of Recipe: Baked Fish Tacos with Cilantro Lime Sauce and Pico de "Guyo"
#
# Explanation of any substitutions made:
# - Made substitutions to reduce fat content by using low-fat dairy alternatives (non-fat Greek yogurt) and reducing the amount of mayonnaise in the cilantro lime sauce.
#
# Modified ingredient list:
#
# * 1 pound fresh fish, cut into small cubes
# * 2 tablespoons non-fat Greek yogurt
# * 1 tablespoon olive oil spray
# * 1/4 cup chopped fresh cilantro
# * 2 cloves garlic, minced
# * Juice of 1 lim
# --------------------------------------55---------------------------------------------
# Title of Recipe: Oxtail Stew (Rabo Encendido)
#
# Explanation of substitutions made:
# To modify this recipe to fit a high-protein, low-carbohydrate dietary pattern, I replaced the full-fat ingredients and added more vegetables. Specifically, I removed the red wine, which is relatively high in carbohydrates, and instead used Port as an alternative. I also increased the amount of tomatoes to reduce carbohydrate content.
#
# Modified ingredient list:
# - 5 pounds oxtails, cut into 2-inch thick rounds
# - 1 cu
# --------------------------------------56---------------------------------------------
# Beer-Simmered Bratwurst with Onions and Red Cabbage Sauerkraut (Modified)
#
# This recipe is a solid food dish and does not require modification.
#
# Title of Recipe: Beer-Simmered Bratwurst with Onions and Red Cabbage Sauerkraut
#
# Explanation of Substitutions: None needed.
#
# Modified Ingredient List:
# - 3 large onions, peeled and thinly sliced
# - 2 cloves garlic, smashed
# - 3 pounds precooked bratwurst, pricked with a fork (lean protein source)
# - 6 bottles dark beer (reduces fat content, uses low-carb alt
# --------------------------------------57---------------------------------------------
# Title: Modified Cucumber Feta Salad Dressing
#
# This recipe is a solid food dish and does not require modification as it is meant to be eaten as a standalone salad item.
#
# Modified ingredient list:
# - 1/2 cucumber, peeled and seeded
# - 1/8 cup low-fat Greek yogurt (replaced feta with lower fat content)
# - 1 small garlic clove, chopped and mashed to a paste with 1/16 teaspoon salt
# - freshly ground black pepper to taste
#
# Modified cooking instructions:
# - Chop enough of cucumber to measure 1 cup and in a
# --------------------------------------58---------------------------------------------
# Southwestern-Style Chicken Burritos (Modified)
#
# This recipe is a solid food dish and can be eaten as a standalone meal item.
#
# ### Explanation of Substitutions:
#
# To modify this recipe to fit a high-protein, low-carbohydrate dietary pattern, the following substitutions were made:
# - Cheese was reduced from 2 cups to 1 cup
# - Tortillas were wrapped tightly in foil to reduce cooking time and oil absorption
#
# ### Modified Ingredient List:
#
# * 4 large boneless skinless chicken breast halves (about 1 1/4 p
# --------------------------------------59---------------------------------------------
# Italian Vegetable Salad with Creamy Garlic Dressing
#
# This recipe is a solid food dish and does not require modification.
#
# Modified ingredient list:
# - 2 medium fennel bulbs
# - 1/4 head cauliflower, broken into large florets
# - 1/2 pound asparagus, trimmed
# - 3 large egg yolks
# - 1 garlic clove, grated (use a Microplane)
# - 2 flat anchovy fillets in oil, chopped
# - 1 teaspoon Dijon mustard
# - 1 tablespoon plus 1 teaspoon fresh lemon juice
# - ½ cup low-fat vegetable broth
# - 1/4 cup low-fat Greek yogurt
# - S
# --------------------------------------60---------------------------------------------
# Fresh Fennel Pan Gravy (Modified for High-Protein, Low-Carbohydrate Diet)
#
# Explanation of substitutions: The original recipe used olive oil and butter, but was replaced with turkey fat to reduce fat content. Additionally, low-sodium chicken broth was used instead of Ultimate Turkey Stock.
#
# Modified ingredient list:
# - 2 cups low-sodium chicken broth
# - 1/4 cup chopped fennel fronds (no change)
# - 1/3 cup finely chopped shallot (no change)
# - 2 tablespoons Pernod (anise-flavored liqueur) (reduced fro
# --------------------------------------61---------------------------------------------
# Tiny Chocolate Chip Cookies
#
# This recipe is a solid food dish and does not require modification.
#
# Modified Ingredient List:
#
# - 1 1/4 sticks (10 tablespoons) unsalted butter
# - 2/3 cup packed light brown sugar
# - 1 large egg
# - 1/2 teaspoon vanilla
# - 1 cup almond flour
# - 1/2 teaspoon baking soda
# - 3/4 teaspoon salt
# - 1 1/4 cups low-fat semisweet chocolate chips
#
# Modified Cooking Instructions:
#
# - Preheat oven to 400°F.
# - Beat together butter, sugar, salt, and baking soda in a large bowl with an elect
# --------------------------------------62---------------------------------------------
# Title of Recipe: Citrus Tangerine Semifreddo with Sauce
#
# Explanation of Substitutions Made:
# To align with a high-protein, low-carbohydrate dietary pattern, several substitutions were made without compromising the dish's appeal.
#
# Modified Ingredient List:
#
# - Citrus tangerines
# - Maldon sea salt
# - Greek yogurt (replaced heavy cream)
# - Honey (reduced to minimize sugar content)
# - Tangerine segments (increased for flavor enhancement)
#
# Modified Cooking Instructions:
# 1. Prepare the sauce by boiling tang
# --------------------------------------63---------------------------------------------
# Mushroom Risotto
#
# This recipe is a solid food dish and does not require modification as it can be eaten as a standalone entrée.
#
# Modified ingredient list:
# - 1 cup Arborio rice (substituted with cauliflower rice to reduce carbohydrates)
# - 4 cups vegetable broth
# - 2 tablespoons olive oil (reduced to 1 tablespoon for lower fat content)
# - 1 small onion, finely chopped
# - 2 cloves garlic, minced
# - 8 oz mixed mushrooms (kept as they are high in protein and fiber)
# - 1/4 cup white wine (substituted with
# --------------------------------------64---------------------------------------------
# Lemon Confiture
# This recipe is a non-food item and does not require modification.
#
# Recipe Modification:
# - Replace 6 tablespoons sugar with 1/2 cup (60g) erythritol or other low-carb sweetener to reduce carbohydrates.
# - Use only 3 tablespoons of the lemon juice used in the original recipe, as it can be quite acidic.
# --------------------------------------65---------------------------------------------
# Serrano Chips with Quince Preserves and Manchego
#
# This recipe is a solid food dish that can be eaten as a snack or appetizer.
#
# Modified ingredient list:
# - 1/4 lb thinly sliced Serrano ham (no changes)
# - 1 1/2 cups vegetable oil (reduced to 1 cup, using cooking spray instead of oil where possible)
# - 1 (1/2-lb) wedge Manchego cheese* (no changes)
# - 4 teaspoons quince preserves or membrillo** (no changes)
#
# Modified cooking instructions:
# 1. Heat 1 tablespoon of cooking spray in a 12-inch nonstick sk
# --------------------------------------66---------------------------------------------
# Title of Recipe: Modified French Vinaigrette
#
# Explanation of Substitutions: The recipe has been modified to reduce fat content by using less olive oil and adding more vinegar, which provides a tangy flavor without adding excessive calories.
#
# Modified Ingredient List:
#
# - 2 tablespoons finely chopped shallots
# - 2.5 tablespoons red- or white-wine vinegar
# - 1/4 teaspoon fine sea salt
# - 2 teaspoons Dijon mustard
# - 3 to 4 tablespoons extra-virgin olive oil (reduced from 4-6)
# - Freshly ground black pep
# --------------------------------------67---------------------------------------------
# Sauteed Swiss Chard with Sliced Garlic (Modified)
#
# This recipe is a solid food dish and does not require modification to fit a high-protein, low-carbohydrate dietary pattern.
#
# ### Explanation of Substitutions:
# None made.
#
# ### Modified Ingredient List:
#
# 2 1/2 pounds red and/or green Swiss chard
# 1/4 cup vegetable broth
# 8 large garlic cloves, thinly sliced
#
# ### Modified Cooking Instructions:
#
# Cut thick stalks and ribs from chard leaves. Chop stalks and ribs into 1/2-inch pieces. Cook stalks and rib
# --------------------------------------68---------------------------------------------
# Title of Recipe: Thai Chicken and Shrimp Noodle Salad
#
# Explanation of any substitutions made:
# - The original recipe includes Asian sweet chili sauce, which is high in sugar. A low-carb alternative can be used to reduce the carb content.
#
# Modified ingredient list:
#
# * 2 tablespoons fresh lime juice
# * 2 tablespoons fish sauce (such as nam pla or nuoc nam)
# * 1 tablespoon low-sugar sweet chili sauce substitute (e.g., sriracha sauce)
# * 1 tablespoon vegetable oil
# * 1 tablespoon sugar-free sweetener (e.
# --------------------------------------69---------------------------------------------
# Crispy Crab Phyllo Stacks
#
# This recipe is a solid food dish and does not require modification.
#
# Modified ingredient list:
#
# * 1 package of low-fat phyllo dough (12 sheets)
# * 1/2 cup low-fat cream cheese
# * 1/4 cup low-fat Greek yogurt
# * 1 tablespoon Dijon mustard
# * 1 teaspoon lemon juice
# * 1/4 cup chopped fresh dill
# * 1/4 cup diced cucumber
# * 1/4 cup crab meat (low-mercury, cooked)
# * 2 teaspoons low-sodium chicken broth
# * Salt and pepper to taste
#
# Modified cooking instructions:
#
# 1. Preheat oven to
# --------------------------------------70---------------------------------------------
# Sausage and Mushroom Penne Gratin (Modified)
#
# This recipe was modified to fit a high-protein, low-carbohydrate dietary pattern.
#
# Explanation of substitutions:
#
# * The heavy cream was replaced with 1 cup of non-fat Greek yogurt to reduce fat content and increase protein.
# * The Parmigiano-Reggiano cheese was reduced from ½ cup to ¼ cup to decrease carbohydrate intake.
# * The mozzarella cheese was also reduced from 8 ounces to 4 ounces to lower the fat content.
#
# Modified ingredient list:
#
# * 1 pound d
# --------------------------------------71---------------------------------------------
# Title of Recipe: Teriyaki-Style Chicken
#
# Explanation of Substitutions:
#
# To modify this recipe to fit a high-protein, low-carbohydrate dietary pattern, we have replaced full-fat chicken breast with leaner alternatives and reduced the use of oils. Additionally, we added more vegetables and legumes to increase protein content without increasing carbohydrates.
#
# Modified Ingredient List:
# - 1 boneless, skinless chicken breast (about 3 ounces)
# - 2 cups mixed greens
# - 1 cup cooked brown rice (reduced to
# --------------------------------------72---------------------------------------------
# Grilled Scallop "Ceviche"
#
# This recipe is a solid food dish that can be eaten as a standalone item.
#
# Modified ingredient list:
#
# - 1 1/2 pounds large sea scallops (about 20), tough ligament removed from side of each if attached
# - 3 tablespoons low-fat olive oil (reduced fat)
# - 1 teaspoon salt
# - 1/2 teaspoon black pepper
# - 1 navel orange
# - 2 tablespoons fresh lime juice
# - 3/4 cup mixed vegetables (such as cucumber, bell peppers, onions) (added to reduce carbs)
# - 1 jalapeño pepper (removed to reduc
# --------------------------------------73---------------------------------------------
# **Modified Recipe**
#
# Title of Recipe: Grandmother Walters's Biscuits (High-Protein, Low-Carbohydrate Version)
#
# Explanation of Substitutions Made:
# To modify this recipe to fit a high-protein, low-carbohydrate dietary pattern, I replaced the 5 tablespoons of cold butter with 2.5 tablespoons of unsalted butter (reduced fat) and added 1 large egg white instead of a whole egg to increase protein content.
#
# Modified Ingredient List:
#
# * 2 cups all-purpose flour
# * 2 tablespoons baking powder
# * 2 teaspoon
# --------------------------------------74---------------------------------------------
# Title of Recipe: Shrimp in Ginger Butter Sauce
#
# Explanation of Substitutions:
# No substitutions were made to the original recipe as it already follows a relatively low-carbohydrate and moderate-fat content.
#
# Modified Ingredient List:
# - 6 ounces large shrimp in shell, peeled
# - 2 tablespoons unsalted butter
# - 1 1/2 teaspoons grated peeled ginger
# - 2 tablespoons medium-dry Sherry
# - 2 tablespoons coarsely chopped cilantro
#
# Modified Cooking Instructions:
# 1. Pat shrimp dry and season with salt.
# 2. Heat
# --------------------------------------75---------------------------------------------
# Grilled Pineapple with Almond Butter-Rum Glaze and Vanilla Mascarpone (Modified)
#
# The original recipe is a solid food dish intended to be eaten as a dessert item.
#
# Modifications to fit a high-protein, low-carbohydrate dietary pattern:
#
# * Replaced dark rum with almond extract for flavor
# * Used almond butter instead of regular butter
# * Reduced sugar content by using less brown sugar and adding a hint of stevia (optional)
# * Kept vanilla bean seeds as they are a natural source of protein
#
# Modified i
# --------------------------------------76---------------------------------------------
# Potato, Carrot, and Zucchini Kugel (Modified for High-Protein, Low-Carbohydrate)
#
# This recipe is a solid food dish meant to be eaten as a standalone side dish.
#
# Modifications made to fit a high-protein, low-carbohydrate dietary pattern:
#
# * Replaced cream with non-fat Greek yogurt
# * Used vegetable purée (zucchini) instead of oil for added moisture and flavor
# * Reduced fat content by using leaner protein sources (eggs) and lower-fat cooking methods
#
# Modified ingredient list:
# - 9 large eggs
# - 1 med
# --------------------------------------77---------------------------------------------
# # Modified Recipe: High-Protein, Low-Carbohydrate Mac and Cheese Casserole
#
# Explanation of Substitutions:
# To make this recipe high-protein, low-carbohydrate, I replaced traditional pasta with whole wheat rotini, reduced fat content by using non-fat Greek yogurt instead of cream cheese, and added more protein-rich ingredients like broccoli.
#
# Modified Ingredient List:
# - 8 ounces whole wheat rotini pasta
# - 3 cups fresh broccoli florets
# - 1 medium onion, chopped
# - 3 cloves garlic, minced
# - 4 tablesp
# --------------------------------------78---------------------------------------------
# Tortilla Soup
#
# This recipe is a solid food dish and does not require modification as it is meant to be eaten (in whole or in part) as a standalone food item — such as a snack, side dish, entrée, breakfast, lunch, or dinner item.
# --------------------------------------79---------------------------------------------
# Sourdough Tartlets with Lemon Pastry Cream and Jam Filling
#
# This recipe is a solid food dish intended to be eaten as a snack or dessert item.
#
# Modified ingredients:
# - 1 cup almond flour
# - 1/2 cup coconut flour
# - 1/4 cup granulated sweetener (such as Swerve)
# - 1/4 teaspoon salt
# - 1/2 cup unsalted butter, melted
# - 2 large eggs
# - 1/2 cup lemon juice
# - 1/4 cup non-fat Greek yogurt
# - 1/2 cup powdered sugar
#
# Modified cooking instructions:
# 1. Preheat oven to 375°F (190°C). Line a baking sheet with parc
# --------------------------------------80---------------------------------------------
# **High-Protein, Low-Carbohydrate Modified Recipe**
#
# **Original Recipe:** Szechuan-Style Wonton Soup with Chilli Oil and Spring Onion
#
# **Explanation of Substitutions Made:**
# The recipe has been modified to prioritize lean protein sources, reduce carbohydrates, and lower fat content. High-fat ingredients such as oil, cream, and full-fat cheese have been avoided or substituted with low-fat alternatives.
#
# **Modified Ingredient List:**
#
# * Wonton wrappers (made from egg whites and whole wheat flour)
# *
# --------------------------------------81---------------------------------------------
# Chocolate Hazelnut Torte
# ------------------------
#
# This recipe is a solid food dish and does not require modification as it is meant to be eaten as a standalone dessert item.
#
# Modified Recipe:
#
# Title of Recipe: Low-Carb Chocolate Hazelnut Torte
#
# Substitutions Made:
# - Replaced full-fat cream with low-fat cream to reduce fat content.
# - Used low-fat chocolate alternatives to minimize added sugar and increase protein content.
#
# Modified Ingredient List:
#
# *   8 ounces low-fat dark chocolate, broken in
# --------------------------------------82---------------------------------------------
# Mint Lollipops with Reduced Fat Content
#
# This recipe is a solid food dish meant to be eaten as a standalone snack item.
#
# Modified Ingredient List:
#
# * 1 cup water
# * 3 cups packed mint leaves (peppermint or spearmint)
# * 2 cups sugar-free sweetener (such as stevia or erythritol) - 1:1 substitute for granulated sugar
# * 1 tablespoon light vegetable glycerin instead of corn syrup
# * 1/4 teaspoon pure peppermint or spearmint extract
# * Low-fat cooking spray
#
# Modified Cooking Instructions:
#
# 1. Combine wat
# --------------------------------------83---------------------------------------------
# Peppery Fig and Cider Compote
#
# This recipe is a solid food dish meant to be eaten as a side dish or dessert item.
#
# Modified ingredient list:
# - 8 ounces dried Mission figs, stemmed
# - 1 1/2 cups unfiltered apple cider (reduced sugar to 3 tablespoons due to natural sweetness)
# - 3 (2-inch) strips orange zest
# - 1 Turkish or 1/2 California bay leaf
# - 1 teaspoon black peppercorns, crushed
#
# Modified cooking instructions:
# Boil the modified ingredients (cider, figs, and spices) uncovered until it is sligh
# --------------------------------------84---------------------------------------------
# Tomatillo and Yellow Tomato Salsa with Tortilla Chips
#
# This recipe is a solid food dish that is meant to be eaten as a snack or side dish.
#
# Modified Recipe:
#
# Title of Recipe: Tomatillo and Yellow Tomato Salsa with Low-Carb Tortilla Chips
#
# Explanation of Substitutions:
# To fit the high-protein, low-carbohydrate dietary pattern, we made the following substitutions:
# - Added more protein-rich ingredients such as fish (in place of bacon) to reduce fat content.
# - Reduced the amount of oil used in cooki
# --------------------------------------85---------------------------------------------
# Modified Recipe: Salmon Salad with Fennel, Orange, and Mint (Low-Carb Version)
#
# Explanation of Substitutions:
# To make this recipe fit a high-protein, low-carbohydrate dietary pattern, we replaced the sugar with a small amount of vinegar to reduce the carbohydrate content. We also used only the fennel segments that were released from the orange membranes, minimizing additional carbs.
#
# Modified Ingredient List:
#
# * 1 1-pound salmon fillet with skin
# * 2 navel oranges
# * 4 cups very thinly sliced fenn
# --------------------------------------86---------------------------------------------
# California Grilled Veggie Sandwich
# This recipe is a solid food dish that can be eaten as a standalone item, likely as a lunch or dinner option.
#
# Modified ingredient list:
# 1/4 cup low-fat mayonnaise
# 3 cloves garlic, minced
# 1 tablespoon lemon juice (no change)
# 1/8 cup olive oil reduced to 1/16 cup (no change in overall usage)
# 1 cup sliced red bell peppers
# 1 small zucchini, sliced
# 1 red onion, sliced
# 1 small yellow squash, sliced
# 2 (4-x6-inch) low-fat focaccia bread pieces, split horizontally
#
# Modi
# --------------------------------------87---------------------------------------------
# Title: High-Protein Tomato Black-Eyed Pea Stew
#
# Explanation of substitutions:
# To meet the high-protein, low-carbohydrate dietary pattern, several modifications were made to the original recipe:
#
# - 2 pounds (900g) mashed tomatoes reduced to 1 can (14.5oz) fire-roasted tomatoes in juice and increased portion size to maintain flavor and protein content.
# - 4 teaspoons ancho chili powder or other chili powder replaced with half teaspoon ground cumin, cinnamon, coriander, and a hint of cayenne pepper
# --------------------------------------88---------------------------------------------
# Flaky Cheese Rolls (High-Protein, Low-Carb Version)
#
# Explanation of Substitutions:
# The original recipe has been modified to reduce carbohydrate content by replacing traditional pastry with yufka sheets and reducing the amount of oil used in frying.
#
# Modified Ingredient List:
#
# * 1 cup crumbled feta cheese
# * 1 cup chopped fresh Italian parsley
# * 16 wedge-shaped yufka sheets (from 12- to 16-ounce package)
# * Vegetable cooking spray or broth (instead of oil)
# * Salt and pepper
#
# Modified Cooking Instru
# --------------------------------------89---------------------------------------------
# Title of Recipe: Baked Crab Cakes with Lemon Aioli
#
# Explanation of Substitutions:
# The following substitutions were made to fit a high-protein, low-carbohydrate dietary pattern:
#
# - French fries and baby greens tossed with lemon vinaigrette were removed as they are relatively high in carbohydrates. Instead, the recipe serves as a standalone snack or side dish.
# - The use of white bread was changed to firm white sandwich bread, which is lower in carbs but still provides structure for the crab cakes.
# --------------------------------------90---------------------------------------------
# This recipe is a solid food dish and does not require modification.
#
# Title of Recipe: Best Ever Banana Bread (modified)
#
# Explanation of Substitutions Made:
# The original recipe was modified to reduce carbohydrates while maintaining protein and fat content within the recommended dietary goals. The use of buttermilk, mashed bananas, and vegetable oil were kept to maintain moisture and flavor, while reducing overall carbohydrate content.
#
# Modified Ingredient List:
#
# * 2 eggs
# * 1/3 cup unsweetened alm
# --------------------------------------91---------------------------------------------
# Watermelon-Cucumber Margarita is a drink, cocktail, smoothie, marinade, condiment, dressing, spice mix, sauce, or ingredient prep.
#
# Title: Watermelon-Cucumber Margarita (modified)
#
# Explanation of substitutions made:
#
# * Replaced water with ice to increase protein content.
# * Removed Simple Syrup and Cointreau as high-carb ingredients.
# * Added 1/4 cup Greek yogurt to the recipe to boost protein content.
#
# Modified ingredient list:
# - 1 1/2 cups 1-inch chunks rindless watermelon
# - 6 (1/8-inch-thick)
# --------------------------------------92---------------------------------------------
# This recipe is a drink, cocktail.
# --------------------------------------93---------------------------------------------
# Modified Recipe:
# Spiced Salmon Kebabs (Low-Carb, High-Protein)
#
# This recipe has been modified to fit a high-protein, low-carbohydrate dietary pattern.
#
# Explanation of substitutions made:
# - 2 tablespoons olive oil was replaced with cooking spray to reduce fat content.
# - No other modifications were necessary as the original recipe did not contain excessive amounts of carbohydrates or fats.
#
# Modified ingredient list:
#
# - 1 1/2 pounds skinless salmon fillet (preferably wild), cut into 1" pieces
# - 2 l
# --------------------------------------94---------------------------------------------
# Deer Jerky
#
# This recipe is a non-food item, specifically a method for making jerky and does not require modification. It is meant to be used as an ingredient in other recipes, such as snacks or entrées, but on its own it is not a solid food dish that can be eaten as a standalone item.
# --------------------------------------95---------------------------------------------
# The Way to a Man's Heart
#
# This recipe is not a solid food dish and does not require modification.
#
# Title of Recipe: The Way to a Man's Heart
# Explanation of any substitutions made: None needed as it already meets dietary goals.
# Modified ingredient list: Same as original.
# Modified cooking instructions: Same as original.
# Macronutrient breakdown:
# - Protein: 43.2g
# - Fats: 29.1g
# - Carbohydrates: 18.7g
#
# Confirm whether the final recipe meets macro goals: Yes, it falls within the target ranges of 40
# --------------------------------------96---------------------------------------------
# Armenian Rice Pilaf
#
# This recipe is a solid food dish that is meant to be eaten as a standalone food item — specifically, a side dish.
#
#
# Modified ingredient list:
#
# - 1/2 cup non-fat chicken broth
# - 1 1/2 cups uncooked fine egg noodles
# - 3 cups uncooked low-carb rice
# - 5 (14.5 ounce) cans low-sodium chicken broth ADVERTISEMENT
# - 4 cubes low-sodium chicken bouillon
#
#
# Modified cooking instructions:
#
# 1. Melt non-fat chicken broth in large saucepan over medium-high heat.
# 2. Add the egg noodles and s
# --------------------------------------97---------------------------------------------
# Ham and Chicken Casserole
# This recipe is a solid food dish meant to be eaten as a standalone dinner item.
#
# Modified Recipe:
#
# Title of Recipe: High-Protein Ham and Chicken Casserole
#
# Explanation of Substitutions:
# To modify this recipe to fit a high-protein, low-carbohydrate dietary pattern, several substitutions were made. Lean protein sources were prioritized, and high-fat ingredients like cream, butter, and full-fat cheese were replaced with low-fat alternatives or omitted altogether. The addit
# --------------------------------------98---------------------------------------------
# # Cannoli
#
# This recipe is a solid food dish that can be eaten as a standalone dessert item, specifically a sweet treat with a filling.
#
# ### Modified Ingredients:
# - Ricotta cheese (same)
# - Confectioners' sugar (same)
# - Blanched slivered almonds (same)
# - Mini semi-sweet chocolate chips (same)
# - Almond extract mixed with water (instead of almond liqueur)
#
# ### Modified Cooking Instructions:
#
# 1. In a large bowl, combine ricotta cheese and confectioners' sugar, stirring until well combined.
# 2. Add the
# --------------------------------------99---------------------------------------------
# It Won't Last Cake
#
# This recipe is a solid food dish and does not require modification. It appears to be a traditional fruit cake recipe that can be eaten as a standalone dessert item.

# %%
results_safe = results_df.select("*")
results_safe.toPandas()
# Out:
#                                       original_recipe  \
# 0   Italian Style Hot Dogs\nCooking oil, suitable ...
# 1   Citrus Marinated Olives\n1 pound large green o...
# 2   Green Tea and Ginger Granita\n3 cups water\n1/...
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...
# 4   Tres Leches\n2 cups chilled Homemade Sweetened...
# ..                                                ...
# 95  The Way to a Man's Heart\n1 pound halibut ADVE...
# 96  Armenian Rice Pilaf\n1/2 cup butter ADVERTISEM...
# 97  Ham and Chicken Casserole\n1/2 cup uncooked eg...
# 98  Cannoli\n1 cup confectioners' sugar ADVERTISEM...
# 99  It Won't Last Cake\n1 1/3 cups vegetable oil A...
#
#                                     modified_response
# 0   Italian Style Hot Dogs\n\nThis recipe is a sol...
# 1   Scallop Ceviche\n\nThis recipe is a solid food...
# 2   Green Tea and Ginger Granita\n\nThis recipe is...
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...
# 4   Tres Leches Cake\n\nThis recipe is a solid foo...
# ..                                                ...
# 95  The Way to a Man's Heart\n\nThis recipe is not...
# 96  Armenian Rice Pilaf\n\nThis recipe is a solid ...
# 97  Ham and Chicken Casserole\nThis recipe is a so...
# 98  # Cannoli\n\nThis recipe is a solid food dish ...
# 99  It Won't Last Cake\n\nThis recipe is a solid f...
#
# [100 rows x 2 columns]

# %%
# readability 
from pyspark.sql.functions import udf
from pyspark.sql.types import FloatType, StringType
import textstat

# UDF to calculate Flesch Reading Ease
@udf(FloatType())
def readability_score_udf(text):
    try:
        return textstat.flesch_reading_ease(text)
    except:
        return None

# UDF to calculate grade level
@udf(StringType())
def reading_grade_level_udf(text):
    try:
        return textstat.text_standard(text, float_output=False)
    except:
        return None

# Apply UDFs to your DataFrame
results_df = results_df.withColumn("readability_score", readability_score_udf("modified_response"))
results_df = results_df.withColumn("reading_grade_level", reading_grade_level_udf("modified_response"))

# %%
results_df.toPandas()
# Out:
#                                       original_recipe  \
# 0   Italian Style Hot Dogs\nCooking oil, suitable ...
# 1   Citrus Marinated Olives\n1 pound large green o...
# 2   Green Tea and Ginger Granita\n3 cups water\n1/...
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...
# 4   Tres Leches\n2 cups chilled Homemade Sweetened...
# ..                                                ...
# 95  The Way to a Man's Heart\n1 pound halibut ADVE...
# 96  Armenian Rice Pilaf\n1/2 cup butter ADVERTISEM...
# 97  Ham and Chicken Casserole\n1/2 cup uncooked eg...
# 98  Cannoli\n1 cup confectioners' sugar ADVERTISEM...
# 99  It Won't Last Cake\n1 1/3 cups vegetable oil A...
#
#                                     modified_response  readability_score  \
# 0   Italian Style Hot Dogs\n\nThis recipe is a sol...          54.220001
# 1   Scallop Ceviche\n\nThis recipe is a solid food...          49.860001
# 2   Green Tea and Ginger Granita\n\nThis recipe is...          65.930000
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...          53.099998
# 4   Tres Leches Cake\n\nThis recipe is a solid foo...          32.160000
# ..                                                ...                ...
# 95  The Way to a Man's Heart\n\nThis recipe is not...          52.360001
# 96  Armenian Rice Pilaf\n\nThis recipe is a solid ...          65.120003
# 97  Ham and Chicken Casserole\nThis recipe is a so...          46.470001
# 98  # Cannoli\n\nThis recipe is a solid food dish ...          47.689999
# 99  It Won't Last Cake\n\nThis recipe is a solid f...          54.220001
#
#     reading_grade_level
# 0    9th and 10th grade
# 1   11th and 12th grade
# 2     7th and 8th grade
# 3   10th and 11th grade
# 4   15th and 16th grade
# ..                  ...
# 95    8th and 9th grade
# 96   9th and 10th grade
# 97  10th and 11th grade
# 98  10th and 11th grade
# 99   9th and 10th grade
#
# [100 rows x 4 columns]

# %%
import pandas as pd
import re
import nltk

# Ensure NLTK is ready
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')

# Convert Spark to Pandas
results_pd = results_df.toPandas()

# Add time_mentions column
def extract_time(text):
    if pd.isnull(text):
        return 0
    times = re.findall(r'\d+\s*(minutes|min|hours|hrs)', text.lower())
    return len(times)

results_pd['time_mentions'] = results_pd['modified_response'].apply(extract_time)

# Add verb_count column
def count_verbs(text):
    if pd.isnull(text):
        return 0
    tokens = nltk.word_tokenize(text)
    pos_tags = nltk.pos_tag(tokens)
    verbs = {word.lower() for word, tag in pos_tags if tag.startswith('VB')}
    return len(verbs)

results_pd['verb_count'] = results_pd['modified_response'].apply(count_verbs)

# Convert back to Spark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
results_df = spark.createDataFrame(results_pd)
results_pd
# Out:
# [nltk_data] Downloading package punkt to /Users/jenny/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/jenny/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
#                                       original_recipe  \
# 0   Italian Style Hot Dogs\nCooking oil, suitable ...
# 1   Citrus Marinated Olives\n1 pound large green o...
# 2   Green Tea and Ginger Granita\n3 cups water\n1/...
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...
# 4   Tres Leches\n2 cups chilled Homemade Sweetened...
# ..                                                ...
# 95  The Way to a Man's Heart\n1 pound halibut ADVE...
# 96  Armenian Rice Pilaf\n1/2 cup butter ADVERTISEM...
# 97  Ham and Chicken Casserole\n1/2 cup uncooked eg...
# 98  Cannoli\n1 cup confectioners' sugar ADVERTISEM...
# 99  It Won't Last Cake\n1 1/3 cups vegetable oil A...
#
#                                     modified_response  readability_score  \
# 0   Italian Style Hot Dogs\n\nThis recipe is a sol...          54.220001
# 1   Scallop Ceviche\n\nThis recipe is a solid food...          49.860001
# 2   Green Tea and Ginger Granita\n\nThis recipe is...          65.930000
# 3   Spicy Fried Oysters on Jalapeno Caesar Salad\n...          53.099998
# 4   Tres Leches Cake\n\nThis recipe is a solid foo...          32.160000
# ..                                                ...                ...
# 95  The Way to a Man's Heart\n\nThis recipe is not...          52.360001
# 96  Armenian Rice Pilaf\n\nThis recipe is a solid ...          65.120003
# 97  Ham and Chicken Casserole\nThis recipe is a so...          46.470001
# 98  # Cannoli\n\nThis recipe is a solid food dish ...          47.689999
# 99  It Won't Last Cake\n\nThis recipe is a solid f...          54.220001
#
#     reading_grade_level  time_mentions  verb_count
# 0    9th and 10th grade              0          19
# 1   11th and 12th grade              2          19
# 2     7th and 8th grade              2          25
# 3   10th and 11th grade              2          18
# 4   15th and 16th grade              1          27
# ..                  ...            ...         ...
# 95    8th and 9th grade              0           9
# 96   9th and 10th grade              1          19
# 97  10th and 11th grade              3          36
# 98  10th and 11th grade              0          10
# 99   9th and 10th grade              0           8
#
# [100 rows x 6 columns]

# %%
# faithfulness to the original
from sentence_transformers import SentenceTransformer, util

pandas_df = results_df.select('original_recipe', 'modified_response').toPandas()
model = SentenceTransformer('all-MiniLM-L6-v2')

original_emb = model.encode(pandas_df['original_recipe'].tolist(), convert_to_tensor=True)
modified_emb = model.encode(pandas_df['modified_response'].tolist(), convert_to_tensor=True)

sims = util.cos_sim(original_emb, modified_emb)
pandas_df['faithfulness_score'] = [sims[i][i].item() for i in range(len(pandas_df))]

# Assuming you're still in the same Spark session
faithfulness_scores = spark.createDataFrame(pandas_df[['faithfulness_score']])
results_df = results_df.withColumn("row_index", f.monotonically_increasing_id())
faithfulness_scores = faithfulness_scores.withColumn("row_index", f.monotonically_increasing_id())

results_df = results_df.join(faithfulness_scores, on="row_index").drop("row_index")
results_df.toPandas()
# Out:
#                                       original_recipe  \
# 0   Italian Style Hot Dogs\nCooking oil, suitable ...
# 1   Tomato Salsa\n2 ripe tomatoes, cored and seede...
# 2   Hot Fudge Sauce\n2 cups sugar\n2 cups heavy cr...
# 3   Peppermint Red Velvet Whoopie Pie\n3 cups cake...
# 4   Table of Polenta\n4 cups heavy cream\nPinch of...
# ..                                                ...
# 95  Armenian Rice Pilaf\n1/2 cup butter ADVERTISEM...
# 96  Old Fashioned \n1 scant teaspoon simple syrup\...
# 97  It Won't Last Cake\n1 1/3 cups vegetable oil A...
# 98  Watermelon-Cucumber Margarita \n1 1/2 cups 1-i...
# 99  Best Ever Banana Bread\n2 eggs, beaten ADVERTI...
#
#                                     modified_response  readability_score  \
# 0   Italian Style Hot Dogs\n\nThis recipe is a sol...          54.220001
# 1   Tomato Salsa (High-Protein, Low-Carb Version)\...          36.419998
# 2   Hot Fudge Sauce\nThis recipe is a non-food ite...          43.630001
# 3   This recipe is a solid food dish and does not ...          51.340000
# 4   Title of Recipe: Balsamic Vegetable Grill with...          31.309999
# ..                                                ...                ...
# 95  Armenian Rice Pilaf\n\nThis recipe is a solid ...          65.120003
# 96                  This recipe is a drink, cocktail.          73.849998
# 97  It Won't Last Cake\n\nThis recipe is a solid f...          54.220001
# 98  Watermelon-Cucumber Margarita is a drink, cock...          41.360001
# 99  This recipe is a solid food dish and does not ...          41.799999
#
#     reading_grade_level  time_mentions  verb_count  faithfulness_score
# 0    9th and 10th grade              0          19            0.898883
# 1   14th and 15th grade              0          13            0.688768
# 2   11th and 12th grade              0          20            0.757719
# 3     8th and 9th grade              0           6            0.485934
# 4   14th and 15th grade              1          16            0.548858
# ..                  ...            ...         ...                 ...
# 95   9th and 10th grade              1          19            0.908444
# 96    4th and 5th grade              0           1            0.524474
# 97   9th and 10th grade              0           8            0.606982
# 98  13th and 14th grade              0          20            0.869689
# 99  12th and 13th grade              1          28            0.817537
#
# [100 rows x 7 columns]

# %%
import re
import pandas as pd

# Optional: limit for testing to avoid long loops
# results_df = results_df.limit(50)

# Convert Spark to Pandas
results_pd = results_df.toPandas()

# Function to extract number from LLM response
def extract_score(text): 
    match = re.search(r'\b\d+\b', str(text))
    return int(match.group(0)) if match else None

# Taste evaluation function
def taste_score(text): 
    taste_prompt = f"""
    Based on the following recipe, how tasty do you think the result would be?
    Consider a balance of flavors, ingredients, and cooking method.
    Rate it on a scale from 1 to 10 as a digit.

    Recipe: 
    {text}
    """
    try: 
        response = ollama.chat(
            model="llama3.2", 
            messages=[{"role": "user", "content": taste_prompt}]
        )
        return extract_score(response["message"]["content"])
    except Exception as e:
        return None

# Apply the taste scoring
results_pd["taste_score"] = results_pd["modified_response"].apply(taste_score)

# Convert back to Spark
results_df = spark.createDataFrame(results_pd)
results_pd
# Out:
#                                       original_recipe  \
# 0   Italian Style Hot Dogs\nCooking oil, suitable ...
# 1   Tomato Salsa\n2 ripe tomatoes, cored and seede...
# 2   Hot Fudge Sauce\n2 cups sugar\n2 cups heavy cr...
# 3   Peppermint Red Velvet Whoopie Pie\n3 cups cake...
# 4   Table of Polenta\n4 cups heavy cream\nPinch of...
# ..                                                ...
# 95  Armenian Rice Pilaf\n1/2 cup butter ADVERTISEM...
# 96  Old Fashioned \n1 scant teaspoon simple syrup\...
# 97  It Won't Last Cake\n1 1/3 cups vegetable oil A...
# 98  Watermelon-Cucumber Margarita \n1 1/2 cups 1-i...
# 99  Best Ever Banana Bread\n2 eggs, beaten ADVERTI...
#
#                                     modified_response  readability_score  \
# 0   Italian Style Hot Dogs\n\nThis recipe is a sol...          54.220001
# 1   Tomato Salsa (High-Protein, Low-Carb Version)\...          36.419998
# 2   Hot Fudge Sauce\nThis recipe is a non-food ite...          43.630001
# 3   This recipe is a solid food dish and does not ...          51.340000
# 4   Title of Recipe: Balsamic Vegetable Grill with...          31.309999
# ..                                                ...                ...
# 95  Armenian Rice Pilaf\n\nThis recipe is a solid ...          65.120003
# 96                  This recipe is a drink, cocktail.          73.849998
# 97  It Won't Last Cake\n\nThis recipe is a solid f...          54.220001
# 98  Watermelon-Cucumber Margarita is a drink, cock...          41.360001
# 99  This recipe is a solid food dish and does not ...          41.799999
#
#     reading_grade_level  time_mentions  verb_count  faithfulness_score  \
# 0    9th and 10th grade              0          19            0.898883
# 1   14th and 15th grade              0          13            0.688768
# 2   11th and 12th grade              0          20            0.757719
# 3     8th and 9th grade              0           6            0.485934
# 4   14th and 15th grade              1          16            0.548858
# ..                  ...            ...         ...                 ...
# 95   9th and 10th grade              1          19            0.908444
# 96    4th and 5th grade              0           1            0.524474
# 97   9th and 10th grade              0           8            0.606982
# 98  13th and 14th grade              0          20            0.869689
# 99  12th and 13th grade              1          28            0.817537
#
#     taste_score
# 0           8.0
# 1           6.0
# 2           6.0
# 3           7.0
# 4           8.0
# ..          ...
# 95          6.0
# 96          6.0
# 97          8.0
# 98          7.0
# 99          8.0
#
# [100 rows x 8 columns]
